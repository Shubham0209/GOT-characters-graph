# %% [markdown]
# We can find the data of character interaction networks for George R. R. Martin’s “[A Song of Ice and Fire](https://github.com/mathbeveridge/asoiaf)”.

# %%
import pandas as pd
nodes = pd.read_csv('ASOIAF_nodes.csv')
nodes = nodes['Id']
num_nodes = nodes.shape[0]
nodes
# Out:
# 0                        Addam-Marbrand
# 1           Aegon-Frey-(son-of-Stevron)
# 2                     Aegon-I-Targaryen
# 3      Aegon-Targaryen-(son-of-Rhaegar)
# 4                     Aegon-V-Targaryen
#                      ...
# 791                         Yorko-Terys
# 792                              Ysilla
# 793                   Yurkhaz-zo-Yunzak
# 794                                 Zei
# 795                               Zollo
# Name: Id, Length: 796, dtype: object

# %% [markdown]
# Cool! So we have a list of characters in the variable node. There is a total of 795 nodes (characters). Now let’s explore edges.

# %%
edges = pd.read_csv('ASOIAF_edges.csv',usecols=[0,1] )
edges
# Out:
#                             Source            Target
# 0                   Addam-Marbrand     Brynden-Tully
# 1                   Addam-Marbrand  Cersei-Lannister
# 2                   Addam-Marbrand       Gyles-Rosby
# 3                   Addam-Marbrand   Jaime-Lannister
# 4                   Addam-Marbrand      Jalabhar-Xho
# ...                            ...               ...
# 2818  Walder-Frey-(son-of-Merrett)          Wex-Pyke
# 2819                  Waymar-Royce   Will-(prologue)
# 2820                        Weasel             Weese
# 2821                          Woth             Yoren
# 2822                        Yandry            Ysilla
#
# [2823 rows x 2 columns]

# %% [markdown]
# Visualize Graph with Graphviz
# Graphviz is a Python interface for drawing graphs.

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)

# %%
from graphviz import Digraph
dot = Digraph(comment='VIP graph')

# %% [markdown]
# Let’s visualize the first ten nodes

# %%
nodes_G = []
for node in edges[:10]['Source']:
    if node not in nodes_G:
        nodes_G.append(node)
for node in edges[:10]['Target']:
    if node not in nodes_G:
        nodes_G.append(node)

# %% [markdown]
# Add nodes and edges into the graph

# %%
dot = Digraph(comment='VIP graph')
for i in range(len(nodes_G)):
    dot.node(nodes_G[i])
for i in range(len(edges[:10])):
    edge = edges.iloc[i]
    dot.edge(edge['Source'], edge['Target'])

# %%
dot.render('VIP-graph_10.gv', view=True)
# Out:
# 'VIP-graph_10.gv.pdf'

# %% [markdown]
# Nice! We can see the interactions of Addam-Marbrand clearly in the graph. But how about visualizing the entire network. Of course, we can do that. But we should anticipate that the network of characters in 5 chapters of this series would be huge

# %%
dot = Digraph(comment='VIP graph')
for i in range(num_nodes):
    dot.node(nodes[i])
for i in range(len(edges)):
    edge = edges.iloc[i]
    dot.edge(edge['Source'], edge['Target'])
dot.render('VIP-graph.gv', view=True)
# Out:
# 'VIP-graph.gv.pdf'

# %% [markdown]
# Cool! With graph, we can visualize the network efficiently. But can we create our own graph class?

# %% [markdown]
# Start with creating the vertex (node) class. What attributes and methods do we want our vertex class to have? Hmm. Add connections (*addNeighbor*), know which nodes the current node connect with (*getConnections*), find out the name of the node (*getId* ), and how strong is the connection (*getWeight*)

# %%
## The Vertex

class Vertex:
    def __init__(self,key):
        self.id = key
        self.connectedTo = {}
    
    def addNeighbor(self,nbr,weight=0):
        self.connectedTo[nbr] = weight

    def __str__(self):
        return str(self.id) + ' connectedTo: ' + str([x.id for x in self.connectedTo])

    def getConnections(self):
        return self.connectedTo.keys()

    def getId(self):
        return self.id

    def getWeight(self,nbr):
        return self.connectedTo[nbr]

# %% [markdown]
# Create a graph class with some basic methods of a graph:

# %%
class Graph:
    def __init__(self):
        self.vertList = {}
        self.numVertices = 0

    def addVertex(self,key):
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(key)
        self.vertList[key] = newVertex
        return newVertex

    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t,cost=0):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], cost)

    def getVertices(self):
        return self.vertlist.keys()

    def __iter__(self):
        return iter(self.vertList.values())

# %%
g = Graph()

# %%
for i in range(num_nodes):
    g.addVertex(nodes[i])

# %%
for i in range(len(edges)):
    edge = edges.iloc[i]
    g.addEdge(edge['Source'], edge['Target'])
    g.addEdge(edge['Target'], edge['Source'])

# %%
for v in g:
    for w in v.getConnections():
        print(" %s<->%s" % (v.getId(), w.getId() ) )
# Out:
# Streaming output truncated to the last 5000 lines.
#  Boros-Blount<->Meryn-Trant
#  Boros-Blount<->Osmund-Kettleblack
#  Boros-Blount<->Osney-Kettleblack
#  Boros-Blount<->Sansa-Stark
#  Boros-Blount<->Tanda-Stokeworth
#  Boros-Blount<->Tommen-Baratheon
#  Boros-Blount<->Tyrion-Lannister
#  Bowen-Marsh<->Aemon-Targaryen-(Maester-Aemon)
#  Bowen-Marsh<->Alliser-Thorne
#  Bowen-Marsh<->Cellador
#  Bowen-Marsh<->Cotter-Pyke
#  Bowen-Marsh<->Denys-Mallister
#  Bowen-Marsh<->Donal-Noye
#  Bowen-Marsh<->Eddison-Tollett
#  Bowen-Marsh<->Hobb
#  Bowen-Marsh<->Janos-Slynt
#  Bowen-Marsh<->Jeor-Mormont
#  Bowen-Marsh<->Jon-Snow
#  Bowen-Marsh<->Mance-Rayder
#  Bowen-Marsh<->Othell-Yarwyck
#  Bowen-Marsh<->Samwell-Tarly
#  Bowen-Marsh<->Satin
#  Bowen-Marsh<->Stannis-Baratheon
#  Bowen-Marsh<->Tormund
#  Bowen-Marsh<->Wick-Whittlestick
#  Bran-Stark<->Alebelly
#  Bran-Stark<->Arya-Stark
#  Bran-Stark<->Benjen-Stark
#  Bran-Stark<->Beth-Cassel
#  Bran-Stark<->Brynden-Rivers
#  Bran-Stark<->Catelyn-Stark
#  Bran-Stark<->Cersei-Lannister
#  Bran-Stark<->Chayle
#  Bran-Stark<->Cley-Cerwyn
#  Bran-Stark<->Coldhands
#  Bran-Stark<->Donella-Hornwood
#  Bran-Stark<->Eddard-Stark
#  Bran-Stark<->Hali
#  Bran-Stark<->Hallis-Mollen
#  Bran-Stark<->Hayhead
#  Bran-Stark<->Hodor
#  Bran-Stark<->Howland-Reed
#  Bran-Stark<->Hullen
#  Bran-Stark<->Jeor-Mormont
#  Bran-Stark<->Joffrey-Baratheon
#  Bran-Stark<->Jojen-Reed
#  Bran-Stark<->Jon-Arryn
#  Bran-Stark<->Jon-Snow
#  Bran-Stark<->Jon-Umber-(Greatjon)
#  Bran-Stark<->Jory-Cassel
#  Bran-Stark<->Joseth
#  Bran-Stark<->Leaf
#  Bran-Stark<->Luwin
#  Bran-Stark<->Meera-Reed
#  Bran-Stark<->Mikken
#  Bran-Stark<->Nan
#  Bran-Stark<->Osha
#  Bran-Stark<->Petyr-Baelish
#  Bran-Stark<->Poxy-Tym
#  Bran-Stark<->Ramsay-Snow
#  Bran-Stark<->Reek
#  Bran-Stark<->Renly-Baratheon
#  Bran-Stark<->Rickard-Karstark
#  Bran-Stark<->Rickard-Stark
#  Bran-Stark<->Rickon-Stark
#  Bran-Stark<->Robb-Stark
#  Bran-Stark<->Robert-Baratheon
#  Bran-Stark<->Rodrik-Cassel
#  Bran-Stark<->Samwell-Tarly
#  Bran-Stark<->Sansa-Stark
#  Bran-Stark<->Stafford-Lannister
#  Bran-Stark<->Stiv
#  Bran-Stark<->Theon-Greyjoy
#  Bran-Stark<->Tommen-Baratheon
#  Bran-Stark<->Tyrion-Lannister
#  Bran-Stark<->Walder-Frey-(son-of-Jammos)
#  Bran-Stark<->Walder-Frey-(son-of-Merrett)
#  Bran-Stark<->Wyman-Manderly
#  Bran-Stark<->Yoren
#  Brandon-Norrey<->Jon-Snow
#  Brandon-Norrey<->Torghen-Flint
#  Brandon-Stark<->Aerys-II-Targaryen
#  Brandon-Stark<->Eddard-Stark
#  Brandon-Stark<->Lyanna-Stark
#  Brandon-Stark<->Petyr-Baelish
#  Brandon-Stark<->Rickard-Stark
#  Brandon-Stark<->Rickon-Stark
#  Brandon-Stark<->Robb-Stark
#  Brandon-Stark<->Robert-Baratheon
#  Brea<->Arya-Stark
#  Brea<->Brusco
#  Brea<->Talea
#  Brella<->Sansa-Stark
#  Brella<->Shae
#  Brenett<->Catelyn-Stark
#  Brienne-of-Tarth<->Aerys-II-Targaryen
#  Brienne-of-Tarth<->Biter
#  Brienne-of-Tarth<->Catelyn-Stark
#  Brienne-of-Tarth<->Cersei-Lannister
#  Brienne-of-Tarth<->Clarence-Crabb
#  Brienne-of-Tarth<->Cleos-Frey
#  Brienne-of-Tarth<->Creighton-Longbough
#  Brienne-of-Tarth<->Dick-Crabb
#  Brienne-of-Tarth<->Dontos-Hollard
#  Brienne-of-Tarth<->Edmure-Tully
#  Brienne-of-Tarth<->Elder-Brother
#  Brienne-of-Tarth<->Elmar-Frey
#  Brienne-of-Tarth<->Emmon-Cuy
#  Brienne-of-Tarth<->Gendry
#  Brienne-of-Tarth<->Hyle-Hunt
#  Brienne-of-Tarth<->Illifer
#  Brienne-of-Tarth<->Jaime-Lannister
#  Brienne-of-Tarth<->Jeyne-Heddle
#  Brienne-of-Tarth<->Joffrey-Baratheon
#  Brienne-of-Tarth<->Loras-Tyrell
#  Brienne-of-Tarth<->Lysa-Arryn
#  Brienne-of-Tarth<->Meribald
#  Brienne-of-Tarth<->Narbert
#  Brienne-of-Tarth<->Podrick-Payne
#  Brienne-of-Tarth<->Pyg
#  Brienne-of-Tarth<->Qyburn
#  Brienne-of-Tarth<->Randyll-Tarly
#  Brienne-of-Tarth<->Renly-Baratheon
#  Brienne-of-Tarth<->Robar-Royce
#  Brienne-of-Tarth<->Robb-Stark
#  Brienne-of-Tarth<->Robert-Baratheon
#  Brienne-of-Tarth<->Roose-Bolton
#  Brienne-of-Tarth<->Sandor-Clegane
#  Brienne-of-Tarth<->Sansa-Stark
#  Brienne-of-Tarth<->Selwyn-Tarth
#  Brienne-of-Tarth<->Shagwell
#  Brienne-of-Tarth<->Stannis-Baratheon
#  Brienne-of-Tarth<->Timeon
#  Brienne-of-Tarth<->Tommen-Baratheon
#  Brienne-of-Tarth<->Tyrion-Lannister
#  Brienne-of-Tarth<->Tywin-Lannister
#  Brienne-of-Tarth<->Vargo-Hoat
#  Brienne-of-Tarth<->Vyman
#  Brienne-of-Tarth<->Walton
#  Brienne-of-Tarth<->Willow-Heddle
#  Bronn<->Alayaya
#  Bronn<->Balman-Byrch
#  Bronn<->Catelyn-Stark
#  Bronn<->Cersei-Lannister
#  Bronn<->Chiggen
#  Bronn<->Falyse-Stokeworth
#  Bronn<->Gregor-Clegane
#  Bronn<->Jacelyn-Bywater
#  Bronn<->Joffrey-Baratheon
#  Bronn<->Lollys-Stokeworth
#  Bronn<->Mandon-Moore
#  Bronn<->Marillion
#  Bronn<->Oberyn-Martell
#  Bronn<->Podrick-Payne
#  Bronn<->Rodrik-Cassel
#  Bronn<->Shae
#  Bronn<->Shagga
#  Bronn<->Stannis-Baratheon
#  Bronn<->Timett
#  Bronn<->Tommen-Baratheon
#  Bronn<->Tyrion-Lannister
#  Bronn<->Tywin-Lannister
#  Bronn<->Vardis-Egen
#  Bronn<->Varys
#  Bronn<->Willis-Wode
#  Brus-Buckler<->Malegorn
#  Brus-Buckler<->Narbert-Grandison
#  Brus-Buckler<->Selyse-Florent
#  Brusco<->Arya-Stark
#  Brusco<->Brea
#  Bryce-Caron<->Cortnay-Penrose
#  Bryce-Caron<->Eldon-Estermont
#  Bryce-Caron<->Guyard-Morrigen
#  Bryce-Caron<->Renly-Baratheon
#  Bryce-Caron<->Stannis-Baratheon
#  Brynden-Rivers<->Bran-Stark
#  Brynden-Rivers<->Meera-Reed
#  Brynden-Tully<->Addam-Marbrand
#  Brynden-Tully<->Arya-Stark
#  Brynden-Tully<->Catelyn-Stark
#  Brynden-Tully<->Daven-Lannister
#  Brynden-Tully<->Edmure-Tully
#  Brynden-Tully<->Edwyn-Frey
#  Brynden-Tully<->Emmon-Frey
#  Brynden-Tully<->Hoster-Tully
#  Brynden-Tully<->Jaime-Lannister
#  Brynden-Tully<->Lyle-Crakehall
#  Brynden-Tully<->Lysa-Arryn
#  Brynden-Tully<->Nestor-Royce
#  Brynden-Tully<->Rickard-Karstark
#  Brynden-Tully<->Robb-Stark
#  Brynden-Tully<->Ryman-Frey
#  Brynden-Tully<->Theon-Greyjoy
#  Brynden-Tully<->Tyrion-Lannister
#  Brynden-Tully<->Tywin-Lannister
#  Brynden-Tully<->Walder-Frey
#  Bump<->Varamyr
#  Butterbumps<->Olenna-Redwyne
#  Butterbumps<->Sansa-Stark
#  Byam-Flint<->Craster
#  Caggo<->Gerris-Drinkwater
#  Caggo<->Lucifer-Long
#  Caggo<->Meris
#  Caggo<->Quentyn-Martell
#  Caggo<->Tattered-Prince
#  Caleotte<->Areo-Hotah
#  Caleotte<->Doran-Martell
#  Caleotte<->Gregor-Clegane
#  Caleotte<->Obara-Sand
#  Camarron<->Spotted-Cat
#  Captain-Myraham<->Theon-Greyjoy
#  Captain-Myraham-Daughter<->Theon-Greyjoy
#  Catelyn-Stark<->Aegon-Frey-(son-of-Stevron)
#  Catelyn-Stark<->Arya-Stark
#  Catelyn-Stark<->Balon-Greyjoy
#  Catelyn-Stark<->Beric-Dondarrion
#  Catelyn-Stark<->Bran-Stark
#  Catelyn-Stark<->Brenett
#  Catelyn-Stark<->Brienne-of-Tarth
#  Catelyn-Stark<->Bronn
#  Catelyn-Stark<->Brynden-Tully
#  Catelyn-Stark<->Cersei-Lannister
#  Catelyn-Stark<->Cleos-Frey
#  Catelyn-Stark<->Colemon
#  Catelyn-Stark<->Colen-of-Greenpools
#  Catelyn-Stark<->Dacey-Mormont
#  Catelyn-Stark<->Desmond-Grell
#  Catelyn-Stark<->Donnel-Waynwood
#  Catelyn-Stark<->Eddard-Stark
#  Catelyn-Stark<->Edmure-Tully
#  Catelyn-Stark<->Elmar-Frey
#  Catelyn-Stark<->Eon-Hunter
#  Catelyn-Stark<->Hallis-Mollen
#  Catelyn-Stark<->Hoster-Tully
#  Catelyn-Stark<->Hyle-Hunt
#  Catelyn-Stark<->Jaime-Lannister
#  Catelyn-Stark<->Jason-Mallister
#  Catelyn-Stark<->Jeyne-Westerling
#  Catelyn-Stark<->Joffrey-Baratheon
#  Catelyn-Stark<->Jon-Arryn
#  Catelyn-Stark<->Jon-Snow
#  Catelyn-Stark<->Jon-Umber-(Greatjon)
#  Catelyn-Stark<->Loras-Tyrell
#  Catelyn-Stark<->Lothar-Frey
#  Catelyn-Stark<->Luwin
#  Catelyn-Stark<->Lysa-Arryn
#  Catelyn-Stark<->Maege-Mormont
#  Catelyn-Stark<->Margaery-Tyrell
#  Catelyn-Stark<->Marillion
#  Catelyn-Stark<->Marq-Piper
#  Catelyn-Stark<->Masha-Heddle
#  Catelyn-Stark<->Mathis-Rowan
#  Catelyn-Stark<->Moreo-Tumitis
#  Catelyn-Stark<->Mya-Stone
#  Catelyn-Stark<->Mychel-Redfort
#  Catelyn-Stark<->Nestor-Royce
#  Catelyn-Stark<->Petyr-Baelish
#  Catelyn-Stark<->Randyll-Tarly
#  Catelyn-Stark<->Raynald-Westerling
#  Catelyn-Stark<->Renly-Baratheon
#  Catelyn-Stark<->Rickard-Karstark
#  Catelyn-Stark<->Rickon-Stark
#  Catelyn-Stark<->Robar-Royce
#  Catelyn-Stark<->Robb-Stark
#  Catelyn-Stark<->Robert-Arryn
#  Catelyn-Stark<->Robert-Baratheon
#  Catelyn-Stark<->Robin-Ryger
#  Catelyn-Stark<->Rodrik-Cassel
#  Catelyn-Stark<->Roose-Bolton
#  Catelyn-Stark<->Roslin-Frey
#  Catelyn-Stark<->Ryman-Frey
#  Catelyn-Stark<->Sansa-Stark
#  Catelyn-Stark<->Stafford-Lannister
#  Catelyn-Stark<->Stannis-Baratheon
#  Catelyn-Stark<->Stevron-Frey
#  Catelyn-Stark<->Tansy
#  Catelyn-Stark<->Theon-Greyjoy
#  Catelyn-Stark<->Tyrion-Lannister
#  Catelyn-Stark<->Tytos-Blackwood
#  Catelyn-Stark<->Tywin-Lannister
#  Catelyn-Stark<->Utherydes-Wayn
#  Catelyn-Stark<->Vardis-Egen
#  Catelyn-Stark<->Varys
#  Catelyn-Stark<->Vyman
#  Catelyn-Stark<->Walder-Frey
#  Catelyn-Stark<->Wendel-Manderly
#  Catelyn-Stark<->Willis-Wode
#  Cayn<->Eddard-Stark
#  Cayn<->Renly-Baratheon
#  Cayn<->Tomard
#  Cedra<->Arianne-Martell
#  Cedra<->Garin-(orphan)
#  Cedric-Payne<->Podrick-Payne
#  Cellador<->Bowen-Marsh
#  Cellador<->Clydas
#  Cellador<->Jon-Snow
#  Cellador<->Othell-Yarwyck
#  Cersei-Lannister<->Addam-Marbrand
#  Cersei-Lannister<->Aerys-II-Targaryen
#  Cersei-Lannister<->Alayaya
#  Cersei-Lannister<->Amory-Lorch
#  Cersei-Lannister<->Arya-Stark
#  Cersei-Lannister<->Arys-Oakheart
#  Cersei-Lannister<->Aurane-Waters
#  Cersei-Lannister<->Baelor-I-Targaryen
#  Cersei-Lannister<->Balman-Byrch
#  Cersei-Lannister<->Barristan-Selmy
#  Cersei-Lannister<->Benjen-Stark
#  Cersei-Lannister<->Blue-Bard
#  Cersei-Lannister<->Boros-Blount
#  Cersei-Lannister<->Bran-Stark
#  Cersei-Lannister<->Brienne-of-Tarth
#  Cersei-Lannister<->Bronn
#  Cersei-Lannister<->Catelyn-Stark
#  Cersei-Lannister<->Chiswyck
#  Cersei-Lannister<->Cleos-Frey
#  Cersei-Lannister<->Daenerys-Targaryen
#  Cersei-Lannister<->Doran-Martell
#  Cersei-Lannister<->Dorcas
#  Cersei-Lannister<->Dunsen
#  Cersei-Lannister<->Eddard-Stark
#  Cersei-Lannister<->Elia-Martell
#  Cersei-Lannister<->Ellaria-Sand
#  Cersei-Lannister<->Falyse-Stokeworth
#  Cersei-Lannister<->Garlan-Tyrell
#  Cersei-Lannister<->Garth-Tyrell
#  Cersei-Lannister<->Gregor-Clegane
#  Cersei-Lannister<->Gyles-Rosby
#  Cersei-Lannister<->Harys-Swyft
#  Cersei-Lannister<->High-Septon-(Tyrions)
#  Cersei-Lannister<->High-Sparrow
#  Cersei-Lannister<->Ilyn-Payne
#  Cersei-Lannister<->Jacelyn-Bywater
#  Cersei-Lannister<->Jaime-Lannister
#  Cersei-Lannister<->Jalabhar-Xho
#  Cersei-Lannister<->Janos-Slynt
#  Cersei-Lannister<->Jocelyn-Swyft
#  Cersei-Lannister<->Joffrey-Baratheon
#  Cersei-Lannister<->Jon-Arryn
#  Cersei-Lannister<->Jon-Snow
#  Cersei-Lannister<->Jory-Cassel
#  Cersei-Lannister<->Kevan-Lannister
#  Cersei-Lannister<->Lancel-Lannister
#  Cersei-Lannister<->Loras-Tyrell
#  Cersei-Lannister<->Lysa-Arryn
#  Cersei-Lannister<->Mace-Tyrell
#  Cersei-Lannister<->Maegor-I-Targaryen
#  Cersei-Lannister<->Maggy
#  Cersei-Lannister<->Mandon-Moore
#  Cersei-Lannister<->Margaery-Tyrell
#  Cersei-Lannister<->Mark-Mullendore
#  Cersei-Lannister<->Melara-Hetherspoon
#  Cersei-Lannister<->Meryn-Trant
#  Cersei-Lannister<->Moelle
#  Cersei-Lannister<->Moon-Boy
#  Cersei-Lannister<->Mordane
#  Cersei-Lannister<->Myrcella-Baratheon
#  Cersei-Lannister<->Oberyn-Martell
#  Cersei-Lannister<->Olenna-Redwyne
#  Cersei-Lannister<->Orton-Merryweather
#  Cersei-Lannister<->Osfryd-Kettleblack
#  Cersei-Lannister<->Osmund-Kettleblack
#  Cersei-Lannister<->Osney-Kettleblack
#  Cersei-Lannister<->Petyr-Baelish
#  Cersei-Lannister<->Polliver
#  Cersei-Lannister<->Preston-Greenfield
#  Cersei-Lannister<->Pycelle
#  Cersei-Lannister<->Qyburn
#  Cersei-Lannister<->Rafford
#  Cersei-Lannister<->Raynard
#  Cersei-Lannister<->Renly-Baratheon
#  Cersei-Lannister<->Rhaegar-Targaryen
#  Cersei-Lannister<->Robb-Stark
#  Cersei-Lannister<->Robert-Baratheon
#  Cersei-Lannister<->Robert-Strong
#  Cersei-Lannister<->Sandor-Clegane
#  Cersei-Lannister<->Sansa-Stark
#  Cersei-Lannister<->Scolera
#  Cersei-Lannister<->Senelle
#  Cersei-Lannister<->Shae
#  Cersei-Lannister<->Stannis-Baratheon
#  Cersei-Lannister<->Taena-of-Myr
#  Cersei-Lannister<->Tallad
#  Cersei-Lannister<->Tanda-Stokeworth
#  Cersei-Lannister<->Tickler
#  Cersei-Lannister<->Tommen-Baratheon
#  Cersei-Lannister<->Tyrion-Lannister
#  Cersei-Lannister<->Tywin-Lannister
#  Cersei-Lannister<->Unella
#  Cersei-Lannister<->Varys
#  Cersei-Lannister<->Vayon-Poole
#  Cersei-Lannister<->Vylarr
#  Cersei-Lannister<->Walder-Frey
#  Cersei-Lannister<->Willas-Tyrell
#  Chataya<->Tyrion-Lannister
#  Chayle<->Bran-Stark
#  Chayle<->Mikken
#  Chella<->Shae
#  Chella<->Tyrion-Lannister
#  Chella<->Varys
#  Chett<->Aemon-Targaryen-(Maester-Aemon)
#  Chett<->Jeor-Mormont
#  Chett<->Jon-Snow
#  Chett<->Lark
#  Chett<->Qhorin-Halfhand
#  Chett<->Samwell-Tarly
#  Chett<->Small-Paul
#  Chiggen<->Bronn
#  Chiggen<->Tyrion-Lannister
#  Chiggen<->Willis-Wode
#  Chiswyck<->Amory-Lorch
#  Chiswyck<->Arya-Stark
#  Chiswyck<->Cersei-Lannister
#  Chiswyck<->Dunsen
#  Chiswyck<->Gregor-Clegane
#  Chiswyck<->Ilyn-Payne
#  Chiswyck<->Joffrey-Baratheon
#  Chiswyck<->Meryn-Trant
#  Chiswyck<->Polliver
#  Chiswyck<->Rafford
#  Chiswyck<->Sandor-Clegane
#  Chiswyck<->Tickler
#  Chiswyck<->Weese
#  Clarence-Crabb<->Brienne-of-Tarth
#  Clayton-Suggs<->Asha-Greyjoy
#  Clayton-Suggs<->Godry-Farring
#  Clayton-Suggs<->Stannis-Baratheon
#  Clement-Piper<->Jaime-Lannister
#  Clement-Piper<->Karyl-Vance
#  Cleon<->Daenerys-Targaryen
#  Cleon<->Ghael
#  Cleon<->Quentyn-Martell
#  Cleos-Frey<->Brienne-of-Tarth
#  Cleos-Frey<->Catelyn-Stark
#  Cleos-Frey<->Cersei-Lannister
#  Cleos-Frey<->Eddard-Stark
#  Cleos-Frey<->Jaime-Lannister
#  Cleos-Frey<->Robb-Stark
#  Cleos-Frey<->Tyrion-Lannister
#  Cletus-Yronwood<->Archibald-Yronwood
#  Cletus-Yronwood<->Daenerys-Targaryen
#  Cletus-Yronwood<->Gerris-Drinkwater
#  Cletus-Yronwood<->Kedry
#  Cletus-Yronwood<->Quentyn-Martell
#  Cley-Cerwyn<->Bran-Stark
#  Cley-Cerwyn<->Donella-Hornwood
#  Cley-Cerwyn<->Rodrik-Cassel
#  Clubfoot-Karl<->Craster
#  Clubfoot-Karl<->Samwell-Tarly
#  Clydas<->Aemon-Targaryen-(Maester-Aemon)
#  Clydas<->Cellador
#  Clydas<->Hobb
#  Clydas<->Jon-Snow
#  Clydas<->Mully
#  Clydas<->Samwell-Tarly
#  Clydas<->Stannis-Baratheon
#  Cohollo<->Daenerys-Targaryen
#  Cohollo<->Drogo
#  Cohollo<->Haggo
#  Cohollo<->Qotho
#  Coldhands<->Bran-Stark
#  Coldhands<->Gilly
#  Coldhands<->Hodor
#  Coldhands<->Meera-Reed
#  Colemon<->Catelyn-Stark
#  Colemon<->Gretchel
#  Colemon<->Maddy
#  Colemon<->Petyr-Baelish
#  Colemon<->Robert-Arryn
#  Colemon<->Vardis-Egen
#  Colen-of-Greenpools<->Catelyn-Stark
#  Colen-of-Greenpools<->Renly-Baratheon
#  Conn<->Coratt
#  Conn<->Shagga
#  Conn<->Tyrion-Lannister
#  Coratt<->Conn
#  Corliss-Penny<->Stannis-Baratheon
#  Cortnay-Penrose<->Alester-Florent
#  Cortnay-Penrose<->Bryce-Caron
#  Cortnay-Penrose<->Davos-Seaworth
#  Cortnay-Penrose<->Renly-Baratheon
#  Cortnay-Penrose<->Stannis-Baratheon
#  Cortnay-Penrose<->Tyrion-Lannister
#  Cortnay-Penrose<->Varys
#  Cotter-Pyke<->Aemon-Targaryen-(Maester-Aemon)
#  Cotter-Pyke<->Bowen-Marsh
#  Cotter-Pyke<->Denys-Mallister
#  Cotter-Pyke<->Eddison-Tollett
#  Cotter-Pyke<->Jon-Snow
#  Cotter-Pyke<->Othell-Yarwyck
#  Cotter-Pyke<->Pypar
#  Cotter-Pyke<->Samwell-Tarly
#  Cotter-Pyke<->Selyse-Florent
#  Cotter-Pyke<->Stannis-Baratheon
#  Craster<->Bedwyck
#  Craster<->Byam-Flint
#  Craster<->Clubfoot-Karl
#  Craster<->Dirk
#  Craster<->Dywen
#  Craster<->Eddison-Tollett
#  Craster<->Gilly
#  Craster<->Grenn
#  Craster<->Jeor-Mormont
#  Craster<->Jojen-Reed
#  Craster<->Jon-Snow
#  Craster<->Mance-Rayder
#  Craster<->Samwell-Tarly
#  Craster<->Thoren-Smallwood
#  Craster<->Tormund
#  Creighton-Longbough<->Brienne-of-Tarth
#  Creighton-Longbough<->Illifer
#  Creighton-Longbough<->Shadrich
#  Cressen<->Davos-Seaworth
#  Cressen<->Melisandre
#  Cressen<->Patchface
#  Cressen<->Pylos
#  Cressen<->Renly-Baratheon
#  Cressen<->Robert-Baratheon
#  Cressen<->Selyse-Florent
#  Cressen<->Shireen-Baratheon
#  Cressen<->Stannis-Baratheon
#  Cromm<->Grimtongue
#  Cromm<->Hagen
#  Cutjack<->Gendry
#  Cutjack<->Kurz
#  Cutjack<->Tarber
#  Daario-Naharis<->Aggo
#  Daario-Naharis<->Barristan-Selmy
#  Daario-Naharis<->Ben-Plumm
#  Daario-Naharis<->Daenerys-Targaryen
#  Daario-Naharis<->Drogo
#  Daario-Naharis<->Grey-Worm
#  Daario-Naharis<->Groleo
#  Daario-Naharis<->Hero
#  Daario-Naharis<->Hizdahr-zo-Loraq
#  Daario-Naharis<->Irri
#  Daario-Naharis<->Jhiqui
#  Daario-Naharis<->Jhogo
#  Daario-Naharis<->Jorah-Mormont
#  Daario-Naharis<->Missandei
#  Daario-Naharis<->Prendahl-na-Ghezn
#  Daario-Naharis<->Quentyn-Martell
#  Daario-Naharis<->Rakharo
#  Daario-Naharis<->Sallor
#  Daario-Naharis<->Skahaz-mo-Kandaq
#  Dacey-Mormont<->Catelyn-Stark
#  Dacey-Mormont<->Maege-Mormont
#  Dacey-Mormont<->Robb-Stark
#  Daemon-Sand<->Doran-Martell
#  Daemon-Sand<->Oberyn-Martell
#  Daenerys-Targaryen<->Aegon-I-Targaryen
#  Daenerys-Targaryen<->Aegon-Targaryen-(son-of-Rhaegar)
#  Daenerys-Targaryen<->Aggo
#  Daenerys-Targaryen<->Arstan
#  Daenerys-Targaryen<->Barristan-Selmy
#  Daenerys-Targaryen<->Barsena
#  Daenerys-Targaryen<->Belwas
#  Daenerys-Targaryen<->Ben-Plumm
#  Daenerys-Targaryen<->Benerro
#  Daenerys-Targaryen<->Bloodbeard
#  Daenerys-Targaryen<->Cersei-Lannister
#  Daenerys-Targaryen<->Cleon
#  Daenerys-Targaryen<->Cletus-Yronwood
#  Daenerys-Targaryen<->Cohollo
#  Daenerys-Targaryen<->Daario-Naharis
#  Daenerys-Targaryen<->Daeron-II-Targaryen
#  Daenerys-Targaryen<->Doran-Martell
#  Daenerys-Targaryen<->Doreah
#  Daenerys-Targaryen<->Drogo
#  Daenerys-Targaryen<->Eddard-Stark
#  Daenerys-Targaryen<->Eroeh
#  Daenerys-Targaryen<->Ezzara
#  Daenerys-Targaryen<->Galazza-Galare
#  Daenerys-Targaryen<->Gerris-Drinkwater
#  Daenerys-Targaryen<->Ghael
#  Daenerys-Targaryen<->Grey-Worm
#  Daenerys-Targaryen<->Groleo
#  Daenerys-Targaryen<->Haggo
#  Daenerys-Targaryen<->Hero
#  Daenerys-Targaryen<->Hizdahr-zo-Loraq
#  Daenerys-Targaryen<->Illyrio-Mopatis
#  Daenerys-Targaryen<->Irri
#  Daenerys-Targaryen<->Jhiqui
#  Daenerys-Targaryen<->Jhogo
#  Daenerys-Targaryen<->Jon-Connington
#  Daenerys-Targaryen<->Jorah-Mormont
#  Daenerys-Targaryen<->Kraznys-mo-Nakloz
#  Daenerys-Targaryen<->Lynesse-Hightower
#  Daenerys-Targaryen<->Lysono-Maar
#  Daenerys-Targaryen<->Mace-Tyrell
#  Daenerys-Targaryen<->Marselen
#  Daenerys-Targaryen<->Meris
#  Daenerys-Targaryen<->Mero
#  Daenerys-Targaryen<->Mezzara
#  Daenerys-Targaryen<->Miklaz
#  Daenerys-Targaryen<->Mirri-Maz-Duur
#  Daenerys-Targaryen<->Missandei
#  Daenerys-Targaryen<->Moqorro
#  Daenerys-Targaryen<->Oznak-zo-Pahl
#  Daenerys-Targaryen<->Penny
#  Daenerys-Targaryen<->Pono
#  Daenerys-Targaryen<->Pyat-Pree
#  Daenerys-Targaryen<->Qavo-Nogarys
#  Daenerys-Targaryen<->Qezza
#  Daenerys-Targaryen<->Qotho
#  Daenerys-Targaryen<->Quaithe
#  Daenerys-Targaryen<->Quaro
#  Daenerys-Targaryen<->Quentyn-Martell
#  Daenerys-Targaryen<->Rakharo
#  Daenerys-Targaryen<->Reznak-mo-Reznak
#  Daenerys-Targaryen<->Rhaegar-Targaryen
#  Daenerys-Targaryen<->Rhaegel-Targaryen
#  Daenerys-Targaryen<->Robert-Baratheon
#  Daenerys-Targaryen<->Skahaz-mo-Kandaq
#  Daenerys-Targaryen<->Spotted-Cat
#  Daenerys-Targaryen<->Symon-Stripeback
#  Daenerys-Targaryen<->Tattered-Prince
#  Daenerys-Targaryen<->Tyrion-Lannister
#  Daenerys-Targaryen<->Varys
#  Daenerys-Targaryen<->Victarion-Greyjoy
#  Daenerys-Targaryen<->Viserys-Targaryen
#  Daenerys-Targaryen<->Xaro-Xhoan-Daxos
#  Daenerys-Targaryen<->Yurkhaz-zo-Yunzak
#  Daeron-I-Targaryen<->Shireen-Baratheon
#  Daeron-II-Targaryen<->Aemon-Targaryen-(Maester-Aemon)
#  Daeron-II-Targaryen<->Daenerys-Targaryen
#  Dagmer<->Aeron-Greyjoy
#  Dagmer<->Asha-Greyjoy
#  Dagmer<->Balon-Greyjoy
#  Dagmer<->Rodrik-Cassel
#  Dagmer<->Theon-Greyjoy
#  Dalbridge<->Ebben
#  Dalbridge<->Jon-Snow
#  Dalbridge<->Qhorin-Halfhand
#  Dalla<->Gilly
#  Dalla<->Jon-Snow
#  Dalla<->Mance-Rayder
#  Dalla<->Melisandre
#  Dalla<->Stannis-Baratheon
#  Dalla<->Val
#  Damon-Dance-for-Me<->Grunt
#  Damon-Dance-for-Me<->Ramsay-Snow
#  Damon-Dance-for-Me<->Skinner
#  Damon-Dance-for-Me<->Sour-Alyn
#  Damon-Dance-for-Me<->Theon-Greyjoy
#  Dancy<->Alayaya
#  Danwell-Frey<->Hosteen-Frey
#  Danwell-Frey<->Jared-Frey
#  Danwell-Frey<->Walder-Frey
#  Dareon<->Aemon-Targaryen-(Maester-Aemon)
#  Dareon<->Arya-Stark
#  Dareon<->Gilly
#  Dareon<->Jon-Snow
#  Dareon<->Lanna-(Happy-Port)
#  Dareon<->Samwell-Tarly
#  Daryn-Hornwood<->Eddard-Stark
#  Daryn-Hornwood<->Torrhen-Karstark
#  Daven-Lannister<->Brynden-Tully
#  Daven-Lannister<->Emmon-Frey
#  Daven-Lannister<->Jaime-Lannister
#  Davos-Seaworth<->Alester-Florent
#  Davos-Seaworth<->Allard-Seaworth
#  Davos-Seaworth<->Andrew-Estermont
#  Davos-Seaworth<->Axell-Florent
#  Davos-Seaworth<->Bartimus
#  Davos-Seaworth<->Cortnay-Penrose
#  Davos-Seaworth<->Cressen
#  Davos-Seaworth<->Devan-Seaworth
#  Davos-Seaworth<->Eddard-Stark
#  Davos-Seaworth<->Edric-Storm
#  Davos-Seaworth<->Garth-(Wolfs-Den)
#  Davos-Seaworth<->Godric-Borrell
#  Davos-Seaworth<->Guncer-Sunglass
#  Davos-Seaworth<->Imry-Florent
#  Davos-Seaworth<->Joffrey-Baratheon
#  Davos-Seaworth<->Khorane-Sathmantes
#  Davos-Seaworth<->Lamprey
#  Davos-Seaworth<->Leona-Woolfield
#  Davos-Seaworth<->Marlon-Manderly
#  Davos-Seaworth<->Matthos-Seaworth
#  Davos-Seaworth<->Melisandre
#  Davos-Seaworth<->Monford-Velaryon
#  Davos-Seaworth<->Porridge
#  Davos-Seaworth<->Pylos
#  Davos-Seaworth<->Renly-Baratheon
#  Davos-Seaworth<->Robb-Stark
#  Davos-Seaworth<->Robett-Glover
#  Davos-Seaworth<->Salladhor-Saan
#  Davos-Seaworth<->Selyse-Florent
#  Davos-Seaworth<->Shireen-Baratheon
#  Davos-Seaworth<->Stannis-Baratheon
#  Davos-Seaworth<->Sybell-Spicer
#  Davos-Seaworth<->Wyman-Manderly
#  Denyo-Terys<->Arya-Stark
#  Denyo-Terys<->Ternesio-Terys
#  Denys-Darklyn<->Aerys-II-Targaryen
#  Denys-Mallister<->Aemon-Targaryen-(Maester-Aemon)
#  Denys-Mallister<->Bowen-Marsh
#  Denys-Mallister<->Cotter-Pyke
#  Denys-Mallister<->Eddison-Tollett
#  Denys-Mallister<->Janos-Slynt
#  Denys-Mallister<->Jon-Snow
#  Denys-Mallister<->Othell-Yarwyck
#  Denys-Mallister<->Pypar
#  Denys-Mallister<->Samwell-Tarly
#  Denzo-Dhan<->Meris
#  Desmond<->Arya-Stark
#  Desmond<->Eddard-Stark
#  Desmond-Grell<->Catelyn-Stark
#  Desmond-Grell<->Edmure-Tully
#  Desmond-Grell<->Robb-Stark
#  Desmond-Grell<->Utherydes-Wayn
#  Devan-Seaworth<->Davos-Seaworth
#  Devan-Seaworth<->Jon-Snow
#  Devan-Seaworth<->Melisandre
#  Devan-Seaworth<->Pylos
#  Devan-Seaworth<->Renly-Baratheon
#  Devan-Seaworth<->Stannis-Baratheon
#  Dick-Crabb<->Brienne-of-Tarth
#  Dick-Crabb<->Eustace-Brune
#  Dick-Crabb<->Jaime-Lannister
#  Dick-Crabb<->Podrick-Payne
#  Dick-Crabb<->Renly-Baratheon
#  Dick-Follard<->Jon-Snow
#  Dick-Follard<->Satin
#  Dick-Straw<->Hugh-Hungerford
#  Dick-Straw<->Tattered-Prince
#  Dirk<->Craster
#  Dirk<->Samwell-Tarly
#  Dobber<->Arya-Stark
#  Dolf<->Shagga
#  Donal-Noye<->Aemon-Targaryen-(Maester-Aemon)
#  Donal-Noye<->Bowen-Marsh
#  Donal-Noye<->Jeor-Mormont
#  Donal-Noye<->Jon-Snow
#  Donal-Noye<->Mag-Mar-Tun-Doh-Weg
#  Donal-Noye<->Mance-Rayder
#  Donal-Noye<->Qhorin-Halfhand
#  Donal-Noye<->Stannis-Baratheon
#  Donella-Hornwood<->Bran-Stark
#  Donella-Hornwood<->Cley-Cerwyn
#  Donella-Hornwood<->Leobald-Tallhart
#  Donella-Hornwood<->Luwin
#  Donella-Hornwood<->Mors-Umber
#  Donella-Hornwood<->Ramsay-Snow
#  Donella-Hornwood<->Rodrik-Cassel
#  Donnel-Waynwood<->Catelyn-Stark
#  Dontos-Hollard<->Brienne-of-Tarth
#  Dontos-Hollard<->Joffrey-Baratheon
#  Dontos-Hollard<->Lothor-Brune
#  Dontos-Hollard<->Moon-Boy
#  Dontos-Hollard<->Petyr-Baelish
#  Dontos-Hollard<->Sansa-Stark
#  Dontos-Hollard<->Stannis-Baratheon
#  Dontos-Hollard<->Tyrion-Lannister
#  Dontos-Hollard<->Willas-Tyrell
#  Doran-Martell<->Areo-Hotah
#  Doran-Martell<->Arianne-Martell
#  Doran-Martell<->Arys-Oakheart
#  Doran-Martell<->Balon-Swann
#  Doran-Martell<->Caleotte
#  Doran-Martell<->Cersei-Lannister
#  Doran-Martell<->Daemon-Sand
#  Doran-Martell<->Daenerys-Targaryen
#  Doran-Martell<->Ellaria-Sand
#  Doran-Martell<->Gregor-Clegane
#  Doran-Martell<->Myrcella-Baratheon
#  Doran-Martell<->Nymeria-Sand
#  Doran-Martell<->Obara-Sand
#  Doran-Martell<->Oberyn-Martell
#  Doran-Martell<->Quentyn-Martell
#  Doran-Martell<->Robert-Baratheon
#  Doran-Martell<->Tyene-Sand
#  Doran-Martell<->Tyrion-Lannister
#  Doran-Martell<->Tywin-Lannister
#  Doran-Martell<->Varys
#  Doran-Martell<->Viserys-Targaryen
#  Dorcas<->Cersei-Lannister
#  Dorcas<->Jocelyn-Swyft
#  Dorcas<->Margaery-Tyrell
#  Dorcas<->Osney-Kettleblack
#  Dorcas<->Qyburn
#  Dorcas<->Taena-of-Myr
#  Doreah<->Daenerys-Targaryen
#  Doreah<->Drogo
#  Doreah<->Irri
#  Doreah<->Jhiqui
#  Doreah<->Jorah-Mormont
#  Doreah<->Viserys-Targaryen
#  Draqaz<->Miklaz
#  Drennan<->Squint
#  Drennan<->Theon-Greyjoy
#  Drogo<->Aggo
#  Drogo<->Cohollo
#  Drogo<->Daario-Naharis
#  Drogo<->Daenerys-Targaryen
#  Drogo<->Doreah
#  Drogo<->Haggo
#  Drogo<->Illyrio-Mopatis
#  Drogo<->Irri
#  Drogo<->Jhiqui
#  Drogo<->Jhogo
#  Drogo<->Jommo
#  Drogo<->Jorah-Mormont
#  Drogo<->Mirri-Maz-Duur
#  Drogo<->Ogo
#  Drogo<->Pono
#  Drogo<->Qotho
#  Drogo<->Quaro
#  Drogo<->Rakharo
#  Drogo<->Rhaego
#  Drogo<->Robert-Baratheon
#  Drogo<->Viserys-Targaryen
#  Dryn<->Tormund
#  Dunsen<->Amory-Lorch
#  Dunsen<->Arya-Stark
#  Dunsen<->Cersei-Lannister
#  Dunsen<->Chiswyck
#  Dunsen<->Gregor-Clegane
#  Dunsen<->Ilyn-Payne
#  Dunsen<->Joffrey-Baratheon
#  Dunsen<->Meryn-Trant
#  Dunsen<->Polliver
#  Dunsen<->Rafford
#  Dunsen<->Sandor-Clegane
#  Dunsen<->Tickler
#  Dunsen<->Weese
#  Dunstan-Drumm<->Aeron-Greyjoy
#  Dunstan-Drumm<->Rodrik-Harlaw
#  Dunstan-Drumm<->Victarion-Greyjoy
#  Dywen<->Bannen
#  Dywen<->Bedwyck
#  Dywen<->Craster
#  Dywen<->Eddison-Tollett
#  Dywen<->Grenn
#  Dywen<->Jeor-Mormont
#  Dywen<->Jon-Snow
#  Dywen<->Samwell-Tarly
#  Ebben<->Dalbridge
#  Ebben<->Jon-Snow
#  Ebben<->Qhorin-Halfhand
#  Ebben<->Stonesnake
#  Eddard-Stark<->Aegon-I-Targaryen
#  Eddard-Stark<->Aerys-II-Targaryen
#  Eddard-Stark<->Alyn
#  Eddard-Stark<->Arya-Stark
#  Eddard-Stark<->Balon-Greyjoy
#  Eddard-Stark<->Barristan-Selmy
#  Eddard-Stark<->Beric-Dondarrion
#  Eddard-Stark<->Bran-Stark
#  Eddard-Stark<->Brandon-Stark
#  Eddard-Stark<->Catelyn-Stark
#  Eddard-Stark<->Cayn
#  Eddard-Stark<->Cersei-Lannister
#  Eddard-Stark<->Cleos-Frey
#  Eddard-Stark<->Daenerys-Targaryen
#  Eddard-Stark<->Daryn-Hornwood
#  Eddard-Stark<->Davos-Seaworth
#  Eddard-Stark<->Desmond
#  Eddard-Stark<->Edmure-Tully
#  Eddard-Stark<->Galbart-Glover
#  Eddard-Stark<->Gendry
#  Eddard-Stark<->Gerold-Hightower
#  Eddard-Stark<->Gregor-Clegane
#  Eddard-Stark<->Harwin
#  Eddard-Stark<->High-Septon-(fat_one)
#  Eddard-Stark<->Howland-Reed
#  Eddard-Stark<->Ilyn-Payne
#  Eddard-Stark<->Jacks
#  Eddard-Stark<->Jaime-Lannister
#  Eddard-Stark<->Janos-Slynt
#  Eddard-Stark<->Joffrey-Baratheon
#  Eddard-Stark<->Jon-Arryn
#  Eddard-Stark<->Jon-Snow
#  Eddard-Stark<->Jory-Cassel
#  Eddard-Stark<->Joss
#  Eddard-Stark<->Loras-Tyrell
#  Eddard-Stark<->Luwin
#  Eddard-Stark<->Lyanna-Stark
#  Eddard-Stark<->Lysa-Arryn
#  Eddard-Stark<->Maron-Greyjoy
#  Eddard-Stark<->Marq-Piper
#  Eddard-Stark<->Mordane
#  Eddard-Stark<->Mycah
#  Eddard-Stark<->Petyr-Baelish
#  Eddard-Stark<->Porther
#  Eddard-Stark<->Pycelle
#  Eddard-Stark<->Ramsay-Snow
#  Eddard-Stark<->Raymun-Darry
#  Eddard-Stark<->Renly-Baratheon
#  Eddard-Stark<->Rhaegar-Targaryen
#  Eddard-Stark<->Rickard-Karstark
#  Eddard-Stark<->Rickon-Stark
#  Eddard-Stark<->Robb-Stark
#  Eddard-Stark<->Robert-Baratheon
#  Eddard-Stark<->Rodrik-Cassel
#  Eddard-Stark<->Roose-Bolton
#  Eddard-Stark<->Sandor-Clegane
#  Eddard-Stark<->Sansa-Stark
#  Eddard-Stark<->Stannis-Baratheon
#  Eddard-Stark<->Syrio-Forel
#  Eddard-Stark<->Theon-Greyjoy
#  Eddard-Stark<->Tobho-Mott
#  Eddard-Stark<->Tomard
#  Eddard-Stark<->Torrhen-Karstark
#  Eddard-Stark<->Torrhen-Stark
#  Eddard-Stark<->Tregar
#  Eddard-Stark<->Tyrion-Lannister
#  Eddard-Stark<->Tywin-Lannister
#  Eddard-Stark<->Varly
#  Eddard-Stark<->Varys
#  Eddard-Stark<->Vayon-Poole
#  Eddard-Stark<->Willam-Dustin
#  Eddard-Stark<->Wyl-(guard)
#  Eddard-Stark<->Wylla
#  Eddard-Stark<->Wyman-Manderly
#  Eddison-Tollett<->Aemon-Targaryen-(Maester-Aemon)
#  Eddison-Tollett<->Bedwyck
#  Eddison-Tollett<->Bowen-Marsh
#  Eddison-Tollett<->Cotter-Pyke
#  Eddison-Tollett<->Craster
#  Eddison-Tollett<->Denys-Mallister
#  Eddison-Tollett<->Dywen
#  Eddison-Tollett<->Emmett
#  Eddison-Tollett<->Gilly
#  Eddison-Tollett<->Grenn
#  Eddison-Tollett<->Hobb
#  Eddison-Tollett<->Janos-Slynt
#  Eddison-Tollett<->Jeor-Mormont
#  Eddison-Tollett<->Jon-Snow
#  Eddison-Tollett<->Mully
#  Eddison-Tollett<->Othell-Yarwyck
#  Eddison-Tollett<->Pypar
#  Eddison-Tollett<->Samwell-Tarly
#  Eddison-Tollett<->Satin
#  Eddison-Tollett<->Watt
#  Edmure-Tully<->Brienne-of-Tarth
#  Edmure-Tully<->Brynden-Tully
#  Edmure-Tully<->Catelyn-Stark
#  Edmure-Tully<->Desmond-Grell
#  Edmure-Tully<->Eddard-Stark
#  Edmure-Tully<->Elmar-Frey
#  Edmure-Tully<->Emmon-Frey
#  Edmure-Tully<->Forley-Prester
#  Edmure-Tully<->Hoster-Tully
#  Edmure-Tully<->Ilyn-Payne
#  Edmure-Tully<->Jaime-Lannister
#  Edmure-Tully<->Karyl-Vance
#  Edmure-Tully<->Lothar-Frey
#  Edmure-Tully<->Lysa-Arryn
#  Edmure-Tully<->Marq-Piper
#  Edmure-Tully<->Petyr-Baelish
#  Edmure-Tully<->Robb-Stark
#  Edmure-Tully<->Roslin-Frey
#  Edmure-Tully<->Ryman-Frey
#  Edmure-Tully<->Tansy
#  Edmure-Tully<->Tommen-Baratheon
#  Edmure-Tully<->Tytos-Blackwood
#  Edmure-Tully<->Tywin-Lannister
#  Edmure-Tully<->Walder-Frey
#  Edric-Storm<->Andrew-Estermont
#  Edric-Storm<->Davos-Seaworth
#  Edric-Storm<->Pylos
#  Edric-Storm<->Robert-Baratheon
#  Edric-Storm<->Shireen-Baratheon
#  Edric-Storm<->Stannis-Baratheon
#  Edwyn-Frey<->Brynden-Tully
#  Edwyn-Frey<->Jaime-Lannister
#  Edwyn-Frey<->Ryman-Frey
#  Edwyn-Frey<->Walder-Rivers
#  Elbert-Arryn<->Aerys-II-Targaryen
#  Elder-Brother<->Brienne-of-Tarth
#  Elder-Brother<->Meribald
#  Elder-Brother<->Narbert
#  Eldon-Estermont<->Bryce-Caron
#  Eldon-Estermont<->Steffon-Varner
#  Elia-Martell<->Aegon-Targaryen-(son-of-Rhaegar)
#  Elia-Martell<->Ashara-Dayne
#  Elia-Martell<->Cersei-Lannister
#  Elia-Martell<->Gregor-Clegane
#  Elia-Martell<->Jaime-Lannister
#  Elia-Martell<->Oberyn-Martell
#  Elia-Martell<->Rhaegar-Targaryen
#  Elia-Martell<->Tyrion-Lannister
#  Elia-Martell<->Tywin-Lannister
#  Elinor-Tyrell<->Alla-Tyrell
#  Elinor-Tyrell<->Margaery-Tyrell
#  Elinor-Tyrell<->Megga-Tyrell
#  Elinor-Tyrell<->Sansa-Stark
#  Elinor-Tyrell<->Tallad
#  Ellaria-Sand<->Areo-Hotah
#  Ellaria-Sand<->Arianne-Martell
#  Ellaria-Sand<->Cersei-Lannister
#  Ellaria-Sand<->Doran-Martell
#  Ellaria-Sand<->Oberyn-Martell
#  Ellaria-Sand<->Tyrion-Lannister
#  Elmar-Frey<->Arya-Stark
#  Elmar-Frey<->Brienne-of-Tarth
#  Elmar-Frey<->Catelyn-Stark
#  Elmar-Frey<->Edmure-Tully
#  Elmar-Frey<->Jaime-Lannister
#  Elmar-Frey<->Robb-Stark
#  Elmar-Frey<->Roose-Bolton
#  Elmar-Frey<->Tywin-Lannister
#  Elmar-Frey<->Walder-Frey
#  Elys-Waynwood<->Alys-Arryn
#  Emmett<->Eddison-Tollett
#  Emmett<->Hareth-(Moles-Town)
#  Emmett<->Hop-Robin
#  Emmett<->Janos-Slynt
#  Emmett<->Jon-Snow
#  Emmon-Cuy<->Brienne-of-Tarth
#  Emmon-Cuy<->Renly-Baratheon
#  Emmon-Cuy<->Robar-Royce
#  Emmon-Frey<->Brynden-Tully
#  Emmon-Frey<->Daven-Lannister
#  Emmon-Frey<->Edmure-Tully
#  Emmon-Frey<->Forley-Prester
#  Emmon-Frey<->Genna-Lannister
#  Emmon-Frey<->Jaime-Lannister
#  Emmon-Frey<->Ryman-Frey
#  Emmon-Frey<->Tywin-Lannister
#  Emmond<->Aeron-Greyjoy
#  Emrick<->Arron
#  Emrick<->Hareth-(Moles-Town)
#  Emrick<->Satin
#  Eon-Hunter<->Catelyn-Stark
#  Eon-Hunter<->Lysa-Arryn
#  Eon-Hunter<->Vardis-Egen
#  Eroeh<->Daenerys-Targaryen
#  Errok<->Grigg
#  Errok<->Jon-Snow
#  Errok<->Styr
#  Euron-Greyjoy<->Aeron-Greyjoy
#  Euron-Greyjoy<->Asha-Greyjoy
#  Euron-Greyjoy<->Baelor-Blacktyde
#  Euron-Greyjoy<->Balon-Greyjoy
#  Euron-Greyjoy<->Hotho-Harlaw
#  Euron-Greyjoy<->Humfrey-Hewett
#  Euron-Greyjoy<->Nute
#  Euron-Greyjoy<->Quellon-Greyjoy
#  Euron-Greyjoy<->Red-Oarsman
#  Euron-Greyjoy<->Rodrik-Harlaw
#  Euron-Greyjoy<->Sawane-Botley
#  Euron-Greyjoy<->Theon-Greyjoy
#  Euron-Greyjoy<->Victarion-Greyjoy
#  Eustace-Brune<->Dick-Crabb
#  Ezzara<->Daenerys-Targaryen
#  Falyse-Stokeworth<->Balman-Byrch
#  Falyse-Stokeworth<->Bronn
#  Falyse-Stokeworth<->Cersei-Lannister
#  Falyse-Stokeworth<->Qyburn
#  Farlen<->Theon-Greyjoy
#  Florian-the-Fool<->Jonquil
#  Florian-the-Fool<->Sansa-Stark
#  Fogo<->Ogo
#  Forley-Prester<->Edmure-Tully
#  Forley-Prester<->Emmon-Frey
#  Franklyn-Flowers<->Aegon-Targaryen-(son-of-Rhaegar)
#  Franklyn-Flowers<->Black-Balaq
#  Franklyn-Flowers<->Jon-Connington
#  Franklyn-Fowler<->Arianne-Martell
#  Frenken<->Ballabar
#  Frenya<->Holly
#  Frenya<->Theon-Greyjoy
#  Fulk<->Jon-Snow
#  Fulk<->Mully
#  Galazza-Galare<->Barristan-Selmy
#  Galazza-Galare<->Daenerys-Targaryen
#  Galazza-Galare<->Grazhar
#  Galazza-Galare<->Hizdahr-zo-Loraq
#  Galazza-Galare<->Reznak-mo-Reznak
#  Galazza-Galare<->Skahaz-mo-Kandaq
#  Galbart-Glover<->Asha-Greyjoy
#  Galbart-Glover<->Eddard-Stark
#  Galbart-Glover<->Jaime-Lannister
#  Galbart-Glover<->Jon-Umber-(Greatjon)
#  Galbart-Glover<->Rickard-Karstark
#  Galbart-Glover<->Robb-Stark
#  Galbart-Glover<->Robett-Glover
#  Galbart-Glover<->Roose-Bolton
#  Galyeon-of-Cuy<->Tyrion-Lannister
#  Gared<->Jeor-Mormont
#  Gared<->Waymar-Royce
#  Gared<->Will-(prologue)
#  Garin-(orphan)<->Andrey-Dalt
#  Garin-(orphan)<->Arianne-Martell
#  Garin-(orphan)<->Arys-Oakheart
#  Garin-(orphan)<->Cedra
#  Garin-(orphan)<->Gerold-Dayne
#  Garin-(orphan)<->Myrcella-Baratheon
#  Garin-(orphan)<->Nymeria-Sand
#  Garin-(orphan)<->Sylva-Santagar
#  Garin-(orphan)<->Tyene-Sand
#  Gariss<->Aggar
#  Gariss<->Murch
#  Garlan-Tyrell<->Cersei-Lannister
#  Garlan-Tyrell<->Joffrey-Baratheon
#  Garlan-Tyrell<->Leonette-Fossoway
#  Garlan-Tyrell<->Loras-Tyrell
#  Garlan-Tyrell<->Sansa-Stark
#  Garlan-Tyrell<->Tyrion-Lannister
#  Garlan-Tyrell<->Willas-Tyrell
#  Garrett-Paege<->Jaime-Lannister
#  Garth-(Wolfs-Den)<->Davos-Seaworth
#  Garth-(Wolfs-Den)<->Sybell-Spicer
#  Garth-Greyfeather<->Hairy-Hal
#  Garth-Greyfeather<->Jack-Bulwer
#  Garth-Greyfeather<->Jon-Snow
#  Garth-Tyrell<->Cersei-Lannister
#  Gawen-Westerling<->Jeyne-Westerling
#  Gawen-Westerling<->Sybell-Spicer
#  Gelmarr<->Aggar
#  Gendel<->Gorne
#  Gendel<->Jon-Snow
#  Gendry<->Amory-Lorch
#  Gendry<->Arya-Stark
#  Gendry<->Beric-Dondarrion
#  Gendry<->Brienne-of-Tarth
#  Gendry<->Cutjack
#  Gendry<->Eddard-Stark
#  Gendry<->Greenbeard
#  Gendry<->Harwin
#  Gendry<->Hot-Pie
#  Gendry<->Jaqen-Hghar
#  Gendry<->Lem
#  Gendry<->Lommy-Greenhands
#  Gendry<->Merrit
#  Gendry<->Robert-Baratheon
#  Gendry<->Sandor-Clegane
#  Gendry<->Thoros-of-Myr
#  Gendry<->Tom-of-Sevenstreams
#  Gendry<->Willow-Heddle
#  Gendry<->Woth
#  Gendry<->Yoren
#  Genna-Lannister<->Emmon-Frey
#  Genna-Lannister<->Jaime-Lannister
#  Genna-Lannister<->Tywin-Lannister
#  Gerald-Gower<->Andrew-Estermont
#  Gerold-Dayne<->Arianne-Martell
#  Gerold-Dayne<->Arys-Oakheart
#  Gerold-Dayne<->Balon-Swann
#  Gerold-Dayne<->Garin-(orphan)
#  Gerold-Dayne<->Myrcella-Baratheon
#  Gerold-Grafton<->Terrance-Lynderly
#  Gerold-Hightower<->Aerys-II-Targaryen
#  Gerold-Hightower<->Arthur-Dayne
#  Gerold-Hightower<->Barristan-Selmy
#  Gerold-Hightower<->Eddard-Stark
#  Gerold-Hightower<->Jaime-Lannister
#  Gerold-Hightower<->Lewyn-Martell
#  Gerold-Hightower<->Oswell-Whent
#  Gerold-Hightower<->Robert-Baratheon
#  Gerrick-Kingsblood<->Jon-Snow
#  Gerrick-Kingsblood<->Raymun-Redbeard
#  Gerris-Drinkwater<->Archibald-Yronwood
#  Gerris-Drinkwater<->Barristan-Selmy
#  Gerris-Drinkwater<->Caggo
#  Gerris-Drinkwater<->Cletus-Yronwood
#  Gerris-Drinkwater<->Daenerys-Targaryen
#  Gerris-Drinkwater<->Hizdahr-zo-Loraq
#  Gerris-Drinkwater<->Meris
#  Gerris-Drinkwater<->Quentyn-Martell
#  Gerris-Drinkwater<->Tattered-Prince
#  Ghael<->Cleon
#  Ghael<->Daenerys-Targaryen
#  Gilly<->Aemon-Targaryen-(Maester-Aemon)
#  Gilly<->Coldhands
#  Gilly<->Craster
#  Gilly<->Dalla
#  Gilly<->Dareon
#  Gilly<->Eddison-Tollett
#  Gilly<->Jojen-Reed
#  Gilly<->Jon-Snow
#  Gilly<->Kojja-Mo
#  Gilly<->Mance-Rayder
#  Gilly<->Meera-Reed
#  Gilly<->Melisandre
#  Gilly<->Samwell-Tarly
#  Gilly<->Small-Paul
#  Gilwood-Hunter<->Anya-Waynwood
#  Gilwood-Hunter<->Benedar-Belmore
#  Gilwood-Hunter<->Horton-Redfort
#  Gilwood-Hunter<->Lysa-Arryn
#  Gilwood-Hunter<->Symond-Templeton
#  Godric-Borrell<->Davos-Seaworth
#  Godry-Farring<->Asha-Greyjoy
#  Godry-Farring<->Clayton-Suggs
#  Godry-Farring<->Jon-Snow
#  Godry-Farring<->Justin-Massey
#  Godry-Farring<->Mance-Rayder
#  Godry-Farring<->Melisandre
#  Godry-Farring<->Stannis-Baratheon
#  Goghor-the-Giant<->Belaquo
#  Goghor-the-Giant<->Hizdahr-zo-Loraq
#  Goghor-the-Giant<->Khrazz
#  Goghor-the-Giant<->Spotted-Cat
#  Gormon-Tyrell<->Walgrave
#  Gormond-Goodbrother<->Aeron-Greyjoy
#  Gorne<->Gendel
#  Gorne<->Jon-Snow
#  Gorold-Goodbrother<->Aeron-Greyjoy
#  Gorold-Goodbrother<->Victarion-Greyjoy
#  Grazdan-mo-Eraz<->Mero
#  Grazhar<->Barristan-Selmy
#  Grazhar<->Galazza-Galare
#  Grazhar<->Qezza
#  Greenbeard<->Anguy
#  Greenbeard<->Arya-Stark
#  Greenbeard<->Gendry
#  Greenbeard<->Harwin
#  Greenbeard<->Lem
#  Greenbeard<->Thoros-of-Myr
#  Greenbeard<->Tom-of-Sevenstreams
#  Gregor-Clegane<->Amory-Lorch
#  Gregor-Clegane<->Arya-Stark
#  Gregor-Clegane<->Balon-Swann
#  Gregor-Clegane<->Beric-Dondarrion
#  Gregor-Clegane<->Bronn
#  Gregor-Clegane<->Caleotte
#  Gregor-Clegane<->Cersei-Lannister
#  Gregor-Clegane<->Chiswyck
#  Gregor-Clegane<->Doran-Martell
#  Gregor-Clegane<->Dunsen
#  Gregor-Clegane<->Eddard-Stark
#  Gregor-Clegane<->Elia-Martell
#  Gregor-Clegane<->Helman-Tallhart
#  Gregor-Clegane<->Ilyn-Payne
#  Gregor-Clegane<->Jaime-Lannister
#  Gregor-Clegane<->Joffrey-Baratheon
#  Gregor-Clegane<->Loras-Tyrell
#  Gregor-Clegane<->Marq-Piper
#  Gregor-Clegane<->Meryn-Trant
#  Gregor-Clegane<->Oberyn-Martell
#  Gregor-Clegane<->Petyr-Baelish
#  Gregor-Clegane<->Polliver
#  Gregor-Clegane<->Pycelle
#  Gregor-Clegane<->Qyburn
#  Gregor-Clegane<->Rafford
#  Gregor-Clegane<->Robb-Stark
#  Gregor-Clegane<->Robert-Baratheon
#  Gregor-Clegane<->Sandor-Clegane
#  Gregor-Clegane<->Sansa-Stark
#  Gregor-Clegane<->Tickler
#  Gregor-Clegane<->Tyrion-Lannister
#  Gregor-Clegane<->Tywin-Lannister
#  Gregor-Clegane<->Weese
#  Grenn<->Aemon-Targaryen-(Maester-Aemon)
#  Grenn<->Alliser-Thorne
#  Grenn<->Bedwyck
#  Grenn<->Craster
#  Grenn<->Dywen
#  Grenn<->Eddison-Tollett
#  Grenn<->Halder
#  Grenn<->Jeor-Mormont
#  Grenn<->Jon-Snow
#  Grenn<->Kegs
#  Grenn<->Owen
#  Grenn<->Pypar
#  Grenn<->Samwell-Tarly
#  Grenn<->Small-Paul
#  Grenn<->Todder
#  Gretchel<->Colemon
#  Gretchel<->Maddy
#  Gretchel<->Robert-Arryn
#  Gretchel<->Sansa-Stark
#  Grey-Worm<->Aggo
#  Grey-Worm<->Barristan-Selmy
#  Grey-Worm<->Daario-Naharis
#  Grey-Worm<->Daenerys-Targaryen
#  Grey-Worm<->Hizdahr-zo-Loraq
#  Grey-Worm<->Irri
#  Grey-Worm<->Jorah-Mormont
#  Grey-Worm<->Skahaz-mo-Kandaq
#  Greydon-Goodbrother<->Aeron-Greyjoy
#  Grigg<->Errok
#  Grigg<->Jarl
#  Grigg<->Jon-Snow
#  Grimtongue<->Asha-Greyjoy
#  Grimtongue<->Cromm
#  Grimtongue<->Hagen
#  Grimtongue<->Lorren
#  Grisel<->Petyr-Baelish
#  Groleo<->Barristan-Selmy
#  Groleo<->Daario-Naharis
#  Groleo<->Daenerys-Targaryen
#  Groleo<->Hero
#  Groleo<->Jhogo
#  Groleo<->Skahaz-mo-Kandaq
#  Grunt<->Damon-Dance-for-Me
#  Grunt<->Sour-Alyn
#  Grunt<->Theon-Greyjoy
#  Guncer-Sunglass<->Davos-Seaworth
#  Guncer-Sunglass<->Melisandre
#  Gunthor-son-of-Gurn<->Tyrion-Lannister
#  Guyard-Morrigen<->Bryce-Caron
#  Guyard-Morrigen<->Renly-Baratheon
#  Gyles-Grafton<->Robert-Arryn
#  Gyles-Grafton<->Terrance-Lynderly
#  Gyles-Rosby<->Addam-Marbrand
#  Gyles-Rosby<->Aurane-Waters
#  Gyles-Rosby<->Boros-Blount
#  Gyles-Rosby<->Cersei-Lannister
#  Gyles-Rosby<->Harys-Swyft
#  Gyles-Rosby<->Jacelyn-Bywater
#  Gyles-Rosby<->Jalabhar-Xho
#  Gyles-Rosby<->Joffrey-Baratheon
#  Gyles-Rosby<->Lollys-Stokeworth
#  Gyles-Rosby<->Mace-Tyrell
#  Gyles-Rosby<->Margaery-Tyrell
#  Gyles-Rosby<->Orton-Merryweather
#  Gyles-Rosby<->Pycelle
#  Gyles-Rosby<->Qyburn
#  Gyles-Rosby<->Sansa-Stark
#  Gyles-Rosby<->Tanda-Stokeworth
#  Gyles-Rosby<->Tommen-Baratheon
#  Gyles-Rosby<->Tyrion-Lannister
#  Gynir<->Aggar
#  Gynir<->Wex-Pyke
#  Hagen<->Asha-Greyjoy
#  Hagen<->Cromm
#  Hagen<->Grimtongue
#  Hagen<->Lorren
#  Hagen<->Qarl-the-Maid
#  Hagen<->Tristifer-Botley
#  Haggo<->Cohollo
#  Haggo<->Daenerys-Targaryen
#  Haggo<->Drogo
#  Haggo<->Mirri-Maz-Duur
#  Haggo<->Qotho
#  Haggo<->Rakharo
#  Haggon<->Varamyr
#  Hairy-Hal<->Garth-Greyfeather
#  Hairy-Hal<->Jack-Bulwer
#  Hairy-Hal<->Jon-Snow
#  Hake<->Jon-Snow
#  Halder<->Albett
#  Halder<->Alliser-Thorne
#  Halder<->Grenn
#  Halder<->Jon-Snow
#  Halder<->Pypar
#  Halder<->Rast
#  Halder<->Samwell-Tarly
#  Halder<->Todder
#  Haldon<->Aegon-Targaryen-(son-of-Rhaegar)
#  Haldon<->Benerro
#  Haldon<->Illyrio-Mopatis
#  Haldon<->Jon-Connington
#  Haldon<->Lemore
#  Haldon<->Pono
#  Haldon<->Qavo-Nogarys
#  Haldon<->Rolly-Duckfield
#  Haldon<->Tyrion-Lannister
#  Haldon<->Yandry
#  Haldon<->Ysilla
#  Hali<->Bran-Stark
#  Hallis-Mollen<->Bran-Stark
#  Hallis-Mollen<->Catelyn-Stark
#  Hallis-Mollen<->Luwin
#  Hallis-Mollen<->Robb-Stark
#  Hallis-Mollen<->Theon-Greyjoy
#  Hallis-Mollen<->Wendel-Manderly
#  Hallyne<->Joffrey-Baratheon
#  Hallyne<->Tyrion-Lannister
#  Halys-Hornwood<->Rodrik-Cassel
#  Hareth-(Moles-Town)<->Arron
#  Hareth-(Moles-Town)<->Emmett
#  Hareth-(Moles-Town)<->Emrick
#  Hareth-(Moles-Town)<->Hop-Robin
#  Hareth-(Moles-Town)<->Jon-Snow
#  Hareth-(Moles-Town)<->Kegs
#  Hareth-(Moles-Town)<->Leathers
#  Hareth-(Moles-Town)<->Mully
#  Hareth-(Moles-Town)<->Rory
#  Hareth-(Moles-Town)<->Satin
#  Hareth-(Moles-Town)<->Spare-Boot
#  Harl<->Lorren
#  Harma<->Jarl
#  Harma<->Jon-Snow
#  Harma<->Mance-Rayder
#  Harma<->Rattleshirt
#  Harma<->Styr
#  Harma<->Tormund
#  Harma<->Varamyr
#  Harma<->Weeper
#  Harra<->Amabel
#  Harra<->Arya-Stark
#  Harras-Harlaw<->Victarion-Greyjoy
#  Harren-Hoare<->Aegon-I-Targaryen
#  Harren-Hoare<->Arya-Stark
#  Harren-Hoare<->Nan
#  Harrold-Hardyng<->Anya-Waynwood
#  Harrold-Hardyng<->Robert-Arryn
#  Harrold-Hardyng<->Yohn-Royce
#  Harry-Strickland<->Aegon-Targaryen-(son-of-Rhaegar)
#  Harry-Strickland<->Jon-Connington
#  Harry-Strickland<->Myles-Toyne
#  Harwin<->Alyn
#  Harwin<->Anguy
#  Harwin<->Arya-Stark
#  Harwin<->Beric-Dondarrion
#  Harwin<->Eddard-Stark
#  Harwin<->Gendry
#  Harwin<->Greenbeard
#  Harwin<->Hullen
#  Harwin<->Jory-Cassel
#  Harwin<->Lem
#  Harwin<->Sandor-Clegane
#  Harwood-Stout<->Theon-Greyjoy
#  Harys-Swyft<->Aurane-Waters
#  Harys-Swyft<->Cersei-Lannister
#  Harys-Swyft<->Gyles-Rosby
#  Harys-Swyft<->Jaime-Lannister
#  Harys-Swyft<->Orton-Merryweather
#  Harys-Swyft<->Pycelle
#  Harys-Swyft<->Stannis-Baratheon
#  Harys-Swyft<->Taena-of-Myr
#  Harys-Swyft<->Tommen-Baratheon
#  Hayhead<->Alebelly
#  Hayhead<->Bran-Stark
#  Helman-Tallhart<->Benfred-Tallhart
#  Helman-Tallhart<->Gregor-Clegane
#  Helman-Tallhart<->Randyll-Tarly
#  Helman-Tallhart<->Robett-Glover
#  Hero<->Daario-Naharis
#  Hero<->Daenerys-Targaryen
#  Hero<->Groleo
#  Hero<->Jhogo
#  Heward<->Jory-Cassel
#  Heward<->Wyl-(guard)
#  High-Septon-(fat_one)<->Eddard-Stark
#  High-Septon-(fat_one)<->Joffrey-Baratheon
#  High-Septon-(fat_one)<->Tyrion-Lannister
#  High-Septon-(Tyrions)<->Cersei-Lannister
#  High-Septon-(Tyrions)<->Joffrey-Baratheon
#  High-Septon-(Tyrions)<->Pycelle
#  High-Septon-(Tyrions)<->Tyrion-Lannister
#  High-Sparrow<->Cersei-Lannister
#  High-Sparrow<->Kevan-Lannister
#  High-Sparrow<->Maegor-I-Targaryen
#  High-Sparrow<->Margaery-Tyrell
#  High-Sparrow<->Osney-Kettleblack
#  High-Sparrow<->Taena-of-Myr
#  High-Sparrow<->Tommen-Baratheon
#  High-Sparrow<->Unella
#  Hizdahr-zo-Loraq<->Barristan-Selmy
#  Hizdahr-zo-Loraq<->Belaquo
#  Hizdahr-zo-Loraq<->Belwas
#  Hizdahr-zo-Loraq<->Ben-Plumm
#  Hizdahr-zo-Loraq<->Bloodbeard
#  Hizdahr-zo-Loraq<->Daario-Naharis
#  Hizdahr-zo-Loraq<->Daenerys-Targaryen
#  Hizdahr-zo-Loraq<->Galazza-Galare
#  Hizdahr-zo-Loraq<->Gerris-Drinkwater
#  Hizdahr-zo-Loraq<->Goghor-the-Giant
#  Hizdahr-zo-Loraq<->Grey-Worm
#  Hizdahr-zo-Loraq<->Irri
#  Hizdahr-zo-Loraq<->Jhiqui
#  Hizdahr-zo-Loraq<->Khrazz
#  Hizdahr-zo-Loraq<->Marghaz-zo-Loraq
#  Hizdahr-zo-Loraq<->Missandei
#  Hizdahr-zo-Loraq<->Qezza
#  Hizdahr-zo-Loraq<->Quentyn-Martell
#  Hizdahr-zo-Loraq<->Reznak-mo-Reznak
#  Hizdahr-zo-Loraq<->Skahaz-mo-Kandaq
#  Hizdahr-zo-Loraq<->Spotted-Cat
#  Hizdahr-zo-Loraq<->Steelskin
#  Hobb<->Aemon-Targaryen-(Maester-Aemon)
#  Hobb<->Bowen-Marsh
#  Hobb<->Clydas
#  Hobb<->Eddison-Tollett
#  Hobb<->Janos-Slynt
#  Hobb<->Jon-Snow
#  Hobb<->Melisandre
#  Hobb<->Mully
#  Hobb<->Othell-Yarwyck
#  Hobb<->Owen
#  Hobb<->Samwell-Tarly
#  Hobber-Redwyne<->Horas-Redwyne
#  Hodor<->Bran-Stark
#  Hodor<->Coldhands
#  Hodor<->Jojen-Reed
#  Hodor<->Luwin
#  Hodor<->Meera-Reed
#  Hodor<->Nan
#  Hodor<->Osha
#  Hodor<->Rickon-Stark
#  Hodor<->Robb-Stark
#  Hodor<->Rodrik-Cassel
#  Hodor<->Wyman-Manderly
#  Holly<->Frenya
#  Holly<->Jeyne-Poole
#  Holly<->Rowan
#  Holly<->Theon-Greyjoy
#  Hop-Robin<->Emmett
#  Hop-Robin<->Hareth-(Moles-Town)
#  Hop-Robin<->Jon-Snow
#  Horas-Redwyne<->Hobber-Redwyne
#  Horas-Redwyne<->Joffrey-Baratheon
#  Horton-Redfort<->Anya-Waynwood
#  Horton-Redfort<->Benedar-Belmore
#  Horton-Redfort<->Gilwood-Hunter
#  Horton-Redfort<->Yohn-Royce
#  Hosteen-Frey<->Aenys-Frey
#  Hosteen-Frey<->Danwell-Frey
#  Hosteen-Frey<->Jared-Frey
#  Hosteen-Frey<->Wyman-Manderly
#  Hoster-Blackwood<->Jaime-Lannister
#  Hoster-Tully<->Brynden-Tully
#  Hoster-Tully<->Catelyn-Stark
#  Hoster-Tully<->Edmure-Tully
#  Hoster-Tully<->Jaime-Lannister
#  Hoster-Tully<->Lothar-Frey
#  Hoster-Tully<->Lysa-Arryn
#  Hoster-Tully<->Robb-Stark
#  Hoster-Tully<->Robert-Baratheon
#  Hoster-Tully<->Tansy
#  Hoster-Tully<->Vyman
#  Hot-Pie<->Amory-Lorch
#  Hot-Pie<->Arya-Stark
#  Hot-Pie<->Gendry
#  Hot-Pie<->Lem
#  Hot-Pie<->Lommy-Greenhands
#  Hot-Pie<->Mebble
#  Hot-Pie<->Sharna
#  Hot-Pie<->Tom-of-Sevenstreams
#  Hot-Pie<->Weasel
#  Hot-Pie<->Woth
#  Hot-Pie<->Yoren
#  Hother-Umber<->Jon-Umber-(Greatjon)
#  Hother-Umber<->Mors-Umber
#  Hother-Umber<->Ramsay-Snow
#  Hother-Umber<->Wyman-Manderly
#  Hotho-Harlaw<->Euron-Greyjoy
#  Hotho-Harlaw<->Rodrik-Harlaw
#  Hotho-Harlaw<->Sigfryd-Harlaw
#  Hotho-Harlaw<->Victarion-Greyjoy
#  Howland-Reed<->Bran-Stark
#  Howland-Reed<->Eddard-Stark
#  Hugh<->Jon-Arryn
#  Hugh-Hungerford<->Dick-Straw
#  Hugo-Vance<->Jaime-Lannister
#  Hullen<->Bran-Stark
#  Hullen<->Harwin
#  Hullen<->Jory-Cassel
#  Hullen<->Luwin
#  Hullen<->Robb-Stark
#  Hullen<->Rodrik-Cassel
#  Humfrey-Hewett<->Euron-Greyjoy
#  Humfrey-Hewett<->Victarion-Greyjoy
#  Husband<->Anguy
#  Husband<->Lem
#  Hyle-Hunt<->Brienne-of-Tarth
#  Hyle-Hunt<->Catelyn-Stark
#  Hyle-Hunt<->Meribald
#  Hyle-Hunt<->Podrick-Payne
#  Hyle-Hunt<->Randyll-Tarly
#  Hyle-Hunt<->Sandor-Clegane
#  Hyle-Hunt<->Sansa-Stark
#  Illifer<->Brienne-of-Tarth
#  Illifer<->Creighton-Longbough
#  Illyrio-Mopatis<->Arstan
#  Illyrio-Mopatis<->Belwas
#  Illyrio-Mopatis<->Daenerys-Targaryen
#  Illyrio-Mopatis<->Drogo
#  Illyrio-Mopatis<->Haldon
#  Illyrio-Mopatis<->Irri
#  Illyrio-Mopatis<->Jon-Connington
#  Illyrio-Mopatis<->Jorah-Mormont
#  Illyrio-Mopatis<->Robert-Baratheon
#  Illyrio-Mopatis<->Rolly-Duckfield
#  Illyrio-Mopatis<->Tyrion-Lannister
#  Illyrio-Mopatis<->Viserys-Targaryen
#  Ilyn-Payne<->Amory-Lorch
#  Ilyn-Payne<->Arya-Stark
#  Ilyn-Payne<->Cersei-Lannister
#  Ilyn-Payne<->Chiswyck
#  Ilyn-Payne<->Dunsen
#  Ilyn-Payne<->Eddard-Stark
#  Ilyn-Payne<->Edmure-Tully
#  Ilyn-Payne<->Gregor-Clegane
#  Ilyn-Payne<->Jaime-Lannister
#  Ilyn-Payne<->Jeyne-Poole
#  Ilyn-Payne<->Joffrey-Baratheon
#  Ilyn-Payne<->Loras-Tyrell
#  Ilyn-Payne<->Lyle-Crakehall
#  Ilyn-Payne<->Meryn-Trant
#  Ilyn-Payne<->Polliver
#  Ilyn-Payne<->Rafford
#  Ilyn-Payne<->Robert-Baratheon
#  Ilyn-Payne<->Sandor-Clegane
#  Ilyn-Payne<->Sansa-Stark
#  Ilyn-Payne<->Tickler
#  Ilyn-Payne<->Tyrion-Lannister
#  Ilyn-Payne<->Varys
#  Imry-Florent<->Davos-Seaworth
#  Irri<->Belaquo
#  Irri<->Daario-Naharis
#  Irri<->Daenerys-Targaryen
#  Irri<->Doreah
#  Irri<->Drogo
#  Irri<->Grey-Worm
#  Irri<->Hizdahr-zo-Loraq
#  Irri<->Illyrio-Mopatis
#  Irri<->Jhiqui
#  Irri<->Jhogo
#  Irri<->Jorah-Mormont
#  Irri<->Missandei
#  Irri<->Rakharo
#  Irri<->Skahaz-mo-Kandaq
#  Irri<->Viserys-Targaryen
#  Jacelyn-Bywater<->Bronn
#  Jacelyn-Bywater<->Cersei-Lannister
#  Jacelyn-Bywater<->Gyles-Rosby
#  Jacelyn-Bywater<->Janos-Slynt
#  Jacelyn-Bywater<->Joffrey-Baratheon
#  Jacelyn-Bywater<->Lancel-Lannister
#  Jacelyn-Bywater<->Tommen-Baratheon
#  Jacelyn-Bywater<->Tyrion-Lannister
#  Jacelyn-Bywater<->Varys
#  Jack-Be-Lucky<->Lem
#  Jack-Bulwer<->Beric-Dondarrion
#  Jack-Bulwer<->Garth-Greyfeather
#  Jack-Bulwer<->Hairy-Hal
#  Jack-Bulwer<->Jon-Snow
#  Jack-Bulwer<->Thoros-of-Myr
#  Jacks<->Eddard-Stark
#  Jaehaerys-I-Targaryen<->Maegor-I-Targaryen
#  Jafer-Flowers<->Jaremy-Rykker
#  Jaime-Lannister<->Addam-Marbrand
#  Jaime-Lannister<->Aemon-Targaryen-(Dragonknight)
#  Jaime-Lannister<->Aerys-II-Targaryen
#  Jaime-Lannister<->Amerei-Frey
#  Jaime-Lannister<->Amory-Lorch
#  Jaime-Lannister<->Arya-Stark
#  Jaime-Lannister<->Balon-Swann
#  Jaime-Lannister<->Barristan-Selmy
#  Jaime-Lannister<->Beric-Dondarrion
#  Jaime-Lannister<->Bonifer-Hasty
#  Jaime-Lannister<->Boros-Blount
#  Jaime-Lannister<->Brienne-of-Tarth
#  Jaime-Lannister<->Brynden-Tully
#  Jaime-Lannister<->Catelyn-Stark
#  Jaime-Lannister<->Cersei-Lannister
#  Jaime-Lannister<->Clement-Piper
#  Jaime-Lannister<->Cleos-Frey
#  Jaime-Lannister<->Daven-Lannister
#  Jaime-Lannister<->Dick-Crabb
#  Jaime-Lannister<->Eddard-Stark
#  Jaime-Lannister<->Edmure-Tully
#  Jaime-Lannister<->Edwyn-Frey
#  Jaime-Lannister<->Elia-Martell
#  Jaime-Lannister<->Elmar-Frey
#  Jaime-Lannister<->Emmon-Frey
#  Jaime-Lannister<->Galbart-Glover
#  Jaime-Lannister<->Garrett-Paege
#  Jaime-Lannister<->Genna-Lannister
#  Jaime-Lannister<->Gerold-Hightower
#  Jaime-Lannister<->Gregor-Clegane
#  Jaime-Lannister<->Harys-Swyft
#  Jaime-Lannister<->Hoster-Blackwood
#  Jaime-Lannister<->Hoster-Tully
#  Jaime-Lannister<->Hugo-Vance
#  Jaime-Lannister<->Ilyn-Payne
#  Jaime-Lannister<->Joffrey-Baratheon
#  Jaime-Lannister<->Jon-Arryn
#  Jaime-Lannister<->Jon-Snow
#  Jaime-Lannister<->Jonos-Bracken
#  Jaime-Lannister<->Jory-Cassel
#  Jaime-Lannister<->Josmyn-Peckledon
#  Jaime-Lannister<->Joy-Hill
#  Jaime-Lannister<->Karyl-Vance
#  Jaime-Lannister<->Kevan-Lannister
#  Jaime-Lannister<->Lancel-Lannister
#  Jaime-Lannister<->Lem
#  Jaime-Lannister<->Lewys-Piper
#  Jaime-Lannister<->Loras-Tyrell
#  Jaime-Lannister<->Lyle-Crakehall
#  Jaime-Lannister<->Lysa-Arryn
#  Jaime-Lannister<->Mace-Tyrell
#  Jaime-Lannister<->Mandon-Moore
#  Jaime-Lannister<->Margaery-Tyrell
#  Jaime-Lannister<->Mariya-Darry
#  Jaime-Lannister<->Melara-Hetherspoon
#  Jaime-Lannister<->Meryn-Trant
#  Jaime-Lannister<->Oberyn-Martell
#  Jaime-Lannister<->Olenna-Redwyne
#  Jaime-Lannister<->Osmund-Kettleblack
#  Jaime-Lannister<->Petyr-Baelish
#  Jaime-Lannister<->Pia
#  Jaime-Lannister<->Pycelle
#  Jaime-Lannister<->Qyburn
#  Jaime-Lannister<->Rafford
#  Jaime-Lannister<->Renly-Baratheon
#  Jaime-Lannister<->Rennifer-Longwaters
#  Jaime-Lannister<->Rhaegar-Targaryen
#  Jaime-Lannister<->Rickard-Karstark
#  Jaime-Lannister<->Robb-Stark
#  Jaime-Lannister<->Robert-Baratheon
# ...
#  Torwold-Browntooth<->Lucas-Codd
#  Tregar<->Eddard-Stark
#  Tristifer-Botley<->Asha-Greyjoy
#  Tristifer-Botley<->Hagen
#  Tristifer-Botley<->Qarl-the-Maid
#  Tristifer-IV-Mudd<->Robb-Stark
#  Trystane-Martell<->Myrcella-Baratheon
#  Trystane-Martell<->Quentyn-Martell
#  Tybero-Istarion<->Ben-Plumm
#  Tybero-Istarion<->Kasporio
#  Tybero-Istarion<->Tyrion-Lannister
#  Tycho-Nestoris<->Asha-Greyjoy
#  Tycho-Nestoris<->Jon-Snow
#  Tycho-Nestoris<->Stannis-Baratheon
#  Tyene-Sand<->Andrey-Dalt
#  Tyene-Sand<->Arianne-Martell
#  Tyene-Sand<->Doran-Martell
#  Tyene-Sand<->Garin-(orphan)
#  Tyene-Sand<->Nymeria-Sand
#  Tyene-Sand<->Obara-Sand
#  Tyene-Sand<->Oberyn-Martell
#  Tyene-Sand<->Sarella-Sand
#  Tyene-Sand<->Sylva-Santagar
#  Tyrion-Lannister<->Addam-Marbrand
#  Tyrion-Lannister<->Aegon-I-Targaryen
#  Tyrion-Lannister<->Aegon-Targaryen-(son-of-Rhaegar)
#  Tyrion-Lannister<->Aerys-II-Targaryen
#  Tyrion-Lannister<->Alayaya
#  Tyrion-Lannister<->Allar-Deem
#  Tyrion-Lannister<->Alliser-Thorne
#  Tyrion-Lannister<->Arya-Stark
#  Tyrion-Lannister<->Baelor-I-Targaryen
#  Tyrion-Lannister<->Ballabar
#  Tyrion-Lannister<->Balon-Swann
#  Tyrion-Lannister<->Barristan-Selmy
#  Tyrion-Lannister<->Ben-Plumm
#  Tyrion-Lannister<->Benerro
#  Tyrion-Lannister<->Benjen-Stark
#  Tyrion-Lannister<->Boros-Blount
#  Tyrion-Lannister<->Bran-Stark
#  Tyrion-Lannister<->Brienne-of-Tarth
#  Tyrion-Lannister<->Bronn
#  Tyrion-Lannister<->Brynden-Tully
#  Tyrion-Lannister<->Catelyn-Stark
#  Tyrion-Lannister<->Cersei-Lannister
#  Tyrion-Lannister<->Chataya
#  Tyrion-Lannister<->Chella
#  Tyrion-Lannister<->Chiggen
#  Tyrion-Lannister<->Cleos-Frey
#  Tyrion-Lannister<->Conn
#  Tyrion-Lannister<->Cortnay-Penrose
#  Tyrion-Lannister<->Daenerys-Targaryen
#  Tyrion-Lannister<->Dontos-Hollard
#  Tyrion-Lannister<->Doran-Martell
#  Tyrion-Lannister<->Eddard-Stark
#  Tyrion-Lannister<->Elia-Martell
#  Tyrion-Lannister<->Ellaria-Sand
#  Tyrion-Lannister<->Galyeon-of-Cuy
#  Tyrion-Lannister<->Garlan-Tyrell
#  Tyrion-Lannister<->Gregor-Clegane
#  Tyrion-Lannister<->Gunthor-son-of-Gurn
#  Tyrion-Lannister<->Gyles-Rosby
#  Tyrion-Lannister<->Haldon
#  Tyrion-Lannister<->Hallyne
#  Tyrion-Lannister<->High-Septon-(fat_one)
#  Tyrion-Lannister<->High-Septon-(Tyrions)
#  Tyrion-Lannister<->Illyrio-Mopatis
#  Tyrion-Lannister<->Ilyn-Payne
#  Tyrion-Lannister<->Jacelyn-Bywater
#  Tyrion-Lannister<->Jaime-Lannister
#  Tyrion-Lannister<->Janos-Slynt
#  Tyrion-Lannister<->Jeor-Mormont
#  Tyrion-Lannister<->Joffrey-Baratheon
#  Tyrion-Lannister<->Jon-Arryn
#  Tyrion-Lannister<->Jon-Connington
#  Tyrion-Lannister<->Jon-Snow
#  Tyrion-Lannister<->Jorah-Mormont
#  Tyrion-Lannister<->Jyck
#  Tyrion-Lannister<->Kasporio
#  Tyrion-Lannister<->Kevan-Lannister
#  Tyrion-Lannister<->Kurleket
#  Tyrion-Lannister<->Lancel-Lannister
#  Tyrion-Lannister<->Lemore
#  Tyrion-Lannister<->Leo-Lefford
#  Tyrion-Lannister<->Lollys-Stokeworth
#  Tyrion-Lannister<->Loras-Tyrell
#  Tyrion-Lannister<->Luwin
#  Tyrion-Lannister<->Lysa-Arryn
#  Tyrion-Lannister<->Mace-Tyrell
#  Tyrion-Lannister<->Mandon-Moore
#  Tyrion-Lannister<->Margaery-Tyrell
#  Tyrion-Lannister<->Marillion
#  Tyrion-Lannister<->Meryn-Trant
#  Tyrion-Lannister<->Moqorro
#  Tyrion-Lannister<->Mord
#  Tyrion-Lannister<->Morgo
#  Tyrion-Lannister<->Morrec
#  Tyrion-Lannister<->Myrcella-Baratheon
#  Tyrion-Lannister<->Nurse
#  Tyrion-Lannister<->Oberyn-Martell
#  Tyrion-Lannister<->Olenna-Redwyne
#  Tyrion-Lannister<->Osmund-Kettleblack
#  Tyrion-Lannister<->Paxter-Redwyne
#  Tyrion-Lannister<->Penny
#  Tyrion-Lannister<->Petyr-Baelish
#  Tyrion-Lannister<->Pia
#  Tyrion-Lannister<->Podrick-Payne
#  Tyrion-Lannister<->Preston-Greenfield
#  Tyrion-Lannister<->Pycelle
#  Tyrion-Lannister<->Qavo-Nogarys
#  Tyrion-Lannister<->Renly-Baratheon
#  Tyrion-Lannister<->Rickon-Stark
#  Tyrion-Lannister<->Robb-Stark
#  Tyrion-Lannister<->Robert-Arryn
#  Tyrion-Lannister<->Robert-Baratheon
#  Tyrion-Lannister<->Rodrik-Cassel
#  Tyrion-Lannister<->Rolly-Duckfield
#  Tyrion-Lannister<->Roose-Bolton
#  Tyrion-Lannister<->Sandor-Clegane
#  Tyrion-Lannister<->Sansa-Stark
#  Tyrion-Lannister<->Scar
#  Tyrion-Lannister<->Shae
#  Tyrion-Lannister<->Shagga
#  Tyrion-Lannister<->Shrouded-Lord
#  Tyrion-Lannister<->Stannis-Baratheon
#  Tyrion-Lannister<->Sweets
#  Tyrion-Lannister<->Symon-Silver-Tongue
#  Tyrion-Lannister<->Taena-of-Myr
#  Tyrion-Lannister<->Tanda-Stokeworth
#  Tyrion-Lannister<->Theon-Greyjoy
#  Tyrion-Lannister<->Timett
#  Tyrion-Lannister<->Tommen-Baratheon
#  Tyrion-Lannister<->Tybero-Istarion
#  Tyrion-Lannister<->Tysha
#  Tyrion-Lannister<->Tywin-Lannister
#  Tyrion-Lannister<->Vardis-Egen
#  Tyrion-Lannister<->Varys
#  Tyrion-Lannister<->Viserys-Targaryen
#  Tyrion-Lannister<->Vylarr
#  Tyrion-Lannister<->Willas-Tyrell
#  Tyrion-Lannister<->Willis-Wode
#  Tyrion-Lannister<->Yandry
#  Tyrion-Lannister<->Yezzan-zo-Qaggaz
#  Tyrion-Lannister<->Yoren
#  Tyrion-Lannister<->Ysilla
#  Tysha<->Jaime-Lannister
#  Tysha<->Sansa-Stark
#  Tysha<->Shae
#  Tysha<->Tyrion-Lannister
#  Tytos-Blackwood<->Catelyn-Stark
#  Tytos-Blackwood<->Edmure-Tully
#  Tytos-Blackwood<->Jaime-Lannister
#  Tytos-Blackwood<->Jason-Mallister
#  Tytos-Blackwood<->Jonos-Bracken
#  Tywin-Lannister<->Addam-Marbrand
#  Tywin-Lannister<->Aegon-Targaryen-(son-of-Rhaegar)
#  Tywin-Lannister<->Aerys-II-Targaryen
#  Tywin-Lannister<->Amory-Lorch
#  Tywin-Lannister<->Arya-Stark
#  Tywin-Lannister<->Balon-Greyjoy
#  Tywin-Lannister<->Brienne-of-Tarth
#  Tywin-Lannister<->Bronn
#  Tywin-Lannister<->Brynden-Tully
#  Tywin-Lannister<->Catelyn-Stark
#  Tywin-Lannister<->Cersei-Lannister
#  Tywin-Lannister<->Doran-Martell
#  Tywin-Lannister<->Eddard-Stark
#  Tywin-Lannister<->Edmure-Tully
#  Tywin-Lannister<->Elia-Martell
#  Tywin-Lannister<->Elmar-Frey
#  Tywin-Lannister<->Emmon-Frey
#  Tywin-Lannister<->Genna-Lannister
#  Tywin-Lannister<->Gregor-Clegane
#  Tywin-Lannister<->Jaime-Lannister
#  Tywin-Lannister<->Joanna-Lannister
#  Tywin-Lannister<->Joffrey-Baratheon
#  Tywin-Lannister<->Jon-Connington
#  Tywin-Lannister<->Jon-Umber-(Greatjon)
#  Tywin-Lannister<->Kevan-Lannister
#  Tywin-Lannister<->Lysa-Arryn
#  Tywin-Lannister<->Mace-Tyrell
#  Tywin-Lannister<->Marq-Piper
#  Tywin-Lannister<->Martyn-Lannister
#  Tywin-Lannister<->Oberyn-Martell
#  Tywin-Lannister<->Petyr-Baelish
#  Tywin-Lannister<->Podrick-Payne
#  Tywin-Lannister<->Pycelle
#  Tywin-Lannister<->Renly-Baratheon
#  Tywin-Lannister<->Rhaegar-Targaryen
#  Tywin-Lannister<->Robb-Stark
#  Tywin-Lannister<->Robert-Baratheon
#  Tywin-Lannister<->Roose-Bolton
#  Tywin-Lannister<->Sansa-Stark
#  Tywin-Lannister<->Stannis-Baratheon
#  Tywin-Lannister<->Theon-Greyjoy
#  Tywin-Lannister<->Tommen-Baratheon
#  Tywin-Lannister<->Tyrion-Lannister
#  Tywin-Lannister<->Vargo-Hoat
#  Tywin-Lannister<->Varys
#  Tywin-Lannister<->Walder-Frey
#  Tywin-Lannister<->Weese
#  Tywin-Lannister<->Wylis-Manderly
#  Ulf-son-of-Umar<->Shagga
#  Ulmer<->Jon-Snow
#  Umma<->Arya-Stark
#  Unella<->Cersei-Lannister
#  Unella<->High-Sparrow
#  Unella<->Moelle
#  Unella<->Scolera
#  Urswyck<->Jaime-Lannister
#  Urzen<->Lorren
#  Urzen<->Theon-Greyjoy
#  Utherydes-Wayn<->Catelyn-Stark
#  Utherydes-Wayn<->Desmond-Grell
#  Utherydes-Wayn<->Robb-Stark
#  Val<->Dalla
#  Val<->Jarl
#  Val<->Jon-Snow
#  Val<->Mance-Rayder
#  Val<->Robert-Baratheon
#  Val<->Selyse-Florent
#  Val<->Shireen-Baratheon
#  Val<->Stannis-Baratheon
#  Val<->Tormund
#  Varamyr<->Bump
#  Varamyr<->Haggon
#  Varamyr<->Harma
#  Varamyr<->Jon-Snow
#  Varamyr<->Mance-Rayder
#  Varamyr<->Thistle
#  Vardis-Egen<->Bronn
#  Vardis-Egen<->Catelyn-Stark
#  Vardis-Egen<->Colemon
#  Vardis-Egen<->Eon-Hunter
#  Vardis-Egen<->Lysa-Arryn
#  Vardis-Egen<->Tyrion-Lannister
#  Vargo-Hoat<->Amory-Lorch
#  Vargo-Hoat<->Arya-Stark
#  Vargo-Hoat<->Brienne-of-Tarth
#  Vargo-Hoat<->Jaime-Lannister
#  Vargo-Hoat<->Pyg
#  Vargo-Hoat<->Robett-Glover
#  Vargo-Hoat<->Roose-Bolton
#  Vargo-Hoat<->Rorge
#  Vargo-Hoat<->Tywin-Lannister
#  Vargo-Hoat<->Zollo
#  Varly<->Eddard-Stark
#  Varys<->Addam-Marbrand
#  Varys<->Barristan-Selmy
#  Varys<->Bronn
#  Varys<->Catelyn-Stark
#  Varys<->Cersei-Lannister
#  Varys<->Chella
#  Varys<->Cortnay-Penrose
#  Varys<->Daenerys-Targaryen
#  Varys<->Doran-Martell
#  Varys<->Eddard-Stark
#  Varys<->Ilyn-Payne
#  Varys<->Jacelyn-Bywater
#  Varys<->Jaime-Lannister
#  Varys<->Janos-Slynt
#  Varys<->Joffrey-Baratheon
#  Varys<->Jon-Arryn
#  Varys<->Jon-Connington
#  Varys<->Kevan-Lannister
#  Varys<->Lancel-Lannister
#  Varys<->Lollys-Stokeworth
#  Varys<->Maegor-I-Targaryen
#  Varys<->Mandon-Moore
#  Varys<->Margaery-Tyrell
#  Varys<->Petyr-Baelish
#  Varys<->Pycelle
#  Varys<->Renly-Baratheon
#  Varys<->Robb-Stark
#  Varys<->Robert-Baratheon
#  Varys<->Sansa-Stark
#  Varys<->Shae
#  Varys<->Stannis-Baratheon
#  Varys<->Timett
#  Varys<->Tyrion-Lannister
#  Varys<->Tywin-Lannister
#  Vayon-Poole<->Arya-Stark
#  Vayon-Poole<->Cersei-Lannister
#  Vayon-Poole<->Eddard-Stark
#  Vayon-Poole<->Jory-Cassel
#  Vayon-Poole<->Robert-Baratheon
#  Victarion-Greyjoy<->Aeron-Greyjoy
#  Victarion-Greyjoy<->Asha-Greyjoy
#  Victarion-Greyjoy<->Baelor-Blacktyde
#  Victarion-Greyjoy<->Balon-Greyjoy
#  Victarion-Greyjoy<->Daenerys-Targaryen
#  Victarion-Greyjoy<->Dunstan-Drumm
#  Victarion-Greyjoy<->Euron-Greyjoy
#  Victarion-Greyjoy<->Gorold-Goodbrother
#  Victarion-Greyjoy<->Harras-Harlaw
#  Victarion-Greyjoy<->Hotho-Harlaw
#  Victarion-Greyjoy<->Humfrey-Hewett
#  Victarion-Greyjoy<->Kerwin
#  Victarion-Greyjoy<->Longwater-Pyke
#  Victarion-Greyjoy<->Meldred-Merlyn
#  Victarion-Greyjoy<->Moqorro
#  Victarion-Greyjoy<->Nute
#  Victarion-Greyjoy<->Quellon-Greyjoy
#  Victarion-Greyjoy<->Ralf-(Limper)
#  Victarion-Greyjoy<->Ralf-Stonehouse
#  Victarion-Greyjoy<->Rodrik-Harlaw
#  Victarion-Greyjoy<->Rodrik-Sparr
#  Victarion-Greyjoy<->Talbert-Serry
#  Victarion-Greyjoy<->Theon-Greyjoy
#  Victarion-Greyjoy<->Wulfe
#  Visenya-Targaryen<->Aegon-I-Targaryen
#  Visenya-Targaryen<->Rhaenys-Targaryen
#  Viserys-Targaryen<->Aegon-Targaryen-(son-of-Rhaegar)
#  Viserys-Targaryen<->Aerys-II-Targaryen
#  Viserys-Targaryen<->Daenerys-Targaryen
#  Viserys-Targaryen<->Doran-Martell
#  Viserys-Targaryen<->Doreah
#  Viserys-Targaryen<->Drogo
#  Viserys-Targaryen<->Illyrio-Mopatis
#  Viserys-Targaryen<->Irri
#  Viserys-Targaryen<->Jorah-Mormont
#  Viserys-Targaryen<->Oberyn-Martell
#  Viserys-Targaryen<->Rhaegar-Targaryen
#  Viserys-Targaryen<->Rhaella-Targaryen
#  Viserys-Targaryen<->Robert-Baratheon
#  Viserys-Targaryen<->Tyrion-Lannister
#  Vylarr<->Cersei-Lannister
#  Vylarr<->Tyrion-Lannister
#  Vyman<->Brienne-of-Tarth
#  Vyman<->Catelyn-Stark
#  Vyman<->Hoster-Tully
#  Waif<->Arya-Stark
#  Waif<->Kindly-Man
#  Walda-Frey-(daughter-of-Merrett)<->Roose-Bolton
#  Walda-Frey-(daughter-of-Merrett)<->Theon-Greyjoy
#  Walder-Frey<->Aegon-Frey-(son-of-Stevron)
#  Walder-Frey<->Brynden-Tully
#  Walder-Frey<->Catelyn-Stark
#  Walder-Frey<->Cersei-Lannister
#  Walder-Frey<->Danwell-Frey
#  Walder-Frey<->Edmure-Tully
#  Walder-Frey<->Elmar-Frey
#  Walder-Frey<->Jaime-Lannister
#  Walder-Frey<->Jeyne-Westerling
#  Walder-Frey<->Jon-Umber-(Greatjon)
#  Walder-Frey<->Lothar-Frey
#  Walder-Frey<->Petyr-Frey
#  Walder-Frey<->Pycelle
#  Walder-Frey<->Robb-Stark
#  Walder-Frey<->Roose-Bolton
#  Walder-Frey<->Roslin-Frey
#  Walder-Frey<->Stevron-Frey
#  Walder-Frey<->Theon-Greyjoy
#  Walder-Frey<->Tywin-Lannister
#  Walder-Frey-(son-of-Jammos)<->Bran-Stark
#  Walder-Frey-(son-of-Jammos)<->Theon-Greyjoy
#  Walder-Frey-(son-of-Jammos)<->Walder-Frey-(son-of-Merrett)
#  Walder-Frey-(son-of-Merrett)<->Bran-Stark
#  Walder-Frey-(son-of-Merrett)<->Luwin
#  Walder-Frey-(son-of-Merrett)<->Ramsay-Snow
#  Walder-Frey-(son-of-Merrett)<->Rickon-Stark
#  Walder-Frey-(son-of-Merrett)<->Rodrik-Cassel
#  Walder-Frey-(son-of-Merrett)<->Theon-Greyjoy
#  Walder-Frey-(son-of-Merrett)<->Walder-Frey-(son-of-Jammos)
#  Walder-Frey-(son-of-Merrett)<->Wex-Pyke
#  Walder-Rivers<->Edwyn-Frey
#  Walder-Rivers<->Jaime-Lannister
#  Walder-Rivers<->Lothar-Frey
#  Walder-Rivers<->Robb-Stark
#  Walder-Rivers<->Ryman-Frey
#  Walgrave<->Gormon-Tyrell
#  Walgrave<->Pate-(novice)
#  Walton<->Brienne-of-Tarth
#  Walton<->Jaime-Lannister
#  Walton<->Nage
#  Walton<->Qyburn
#  Walton<->Roose-Bolton
#  Watt<->Eddison-Tollett
#  Waymar-Royce<->Benjen-Stark
#  Waymar-Royce<->Gared
#  Waymar-Royce<->Will-(prologue)
#  Weasel<->Arya-Stark
#  Weasel<->Hot-Pie
#  Weasel<->Lommy-Greenhands
#  Weasel<->Weese
#  Weeper<->Harma
#  Weeper<->Jon-Snow
#  Weeper<->Othell-Yarwyck
#  Weeper<->Rattleshirt
#  Weeper<->Tormund
#  Weese<->Arya-Stark
#  Weese<->Chiswyck
#  Weese<->Dunsen
#  Weese<->Gregor-Clegane
#  Weese<->Jaqen-Hghar
#  Weese<->Polliver
#  Weese<->Tywin-Lannister
#  Weese<->Weasel
#  Wendel-Manderly<->Catelyn-Stark
#  Wendel-Manderly<->Hallis-Mollen
#  Wendel-Manderly<->Jon-Umber-(Greatjon)
#  Wendel-Manderly<->Perwyn-Frey
#  Wendel-Manderly<->Robb-Stark
#  Wendel-Manderly<->Robin-Flint
#  Wendel-Manderly<->Shadd
#  Werlag<->Stygg
#  Werlag<->Theon-Greyjoy
#  Wex-Pyke<->Asha-Greyjoy
#  Wex-Pyke<->Gynir
#  Wex-Pyke<->Lorren
#  Wex-Pyke<->Theon-Greyjoy
#  Wex-Pyke<->Walder-Frey-(son-of-Merrett)
#  Wick-Whittlestick<->Bowen-Marsh
#  Wick-Whittlestick<->Jon-Snow
#  Widower<->Barristan-Selmy
#  Will-(prologue)<->Gared
#  Will-(prologue)<->Waymar-Royce
#  Willam-Dustin<->Eddard-Stark
#  Willam-Dustin<->Robert-Baratheon
#  Willas-Tyrell<->Cersei-Lannister
#  Willas-Tyrell<->Dontos-Hollard
#  Willas-Tyrell<->Garlan-Tyrell
#  Willas-Tyrell<->Loras-Tyrell
#  Willas-Tyrell<->Mace-Tyrell
#  Willas-Tyrell<->Margaery-Tyrell
#  Willas-Tyrell<->Sansa-Stark
#  Willas-Tyrell<->Tyrion-Lannister
#  Willem-Lannister<->Kevan-Lannister
#  Willem-Lannister<->Martyn-Lannister
#  Willem-Lannister<->Robb-Stark
#  Willem-Lannister<->Tion-Frey
#  William-Foxglove<->Stannis-Baratheon
#  Willis-Wode<->Bronn
#  Willis-Wode<->Catelyn-Stark
#  Willis-Wode<->Chiggen
#  Willis-Wode<->Marillion
#  Willis-Wode<->Rodrik-Cassel
#  Willis-Wode<->Tyrion-Lannister
#  Willow-Heddle<->Brienne-of-Tarth
#  Willow-Heddle<->Gendry
#  Willow-Witch-eye<->Theon-Greyjoy
#  Woth<->Arya-Stark
#  Woth<->Gendry
#  Woth<->Hot-Pie
#  Woth<->Lommy-Greenhands
#  Woth<->Yoren
#  Wulfe<->Victarion-Greyjoy
#  Wun-Weg-Wun-Dar-Wun<->Jon-Snow
#  Wun-Weg-Wun-Dar-Wun<->Leathers
#  Wun-Weg-Wun-Dar-Wun<->Patrek-of-Kings-Mountain
#  Wun-Weg-Wun-Dar-Wun<->Selyse-Florent
#  Wyl-(guard)<->Eddard-Stark
#  Wyl-(guard)<->Heward
#  Wyl-(guard)<->Jaime-Lannister
#  Wyl-(guard)<->Jory-Cassel
#  Wylis-Manderly<->Jaime-Lannister
#  Wylis-Manderly<->Tywin-Lannister
#  Wylla<->Eddard-Stark
#  Wyman-Manderly<->Aenys-Frey
#  Wyman-Manderly<->Bran-Stark
#  Wyman-Manderly<->Davos-Seaworth
#  Wyman-Manderly<->Eddard-Stark
#  Wyman-Manderly<->Hodor
#  Wyman-Manderly<->Hosteen-Frey
#  Wyman-Manderly<->Hother-Umber
#  Wyman-Manderly<->Leona-Woolfield
#  Wyman-Manderly<->Ramsay-Snow
#  Wyman-Manderly<->Rhaegar-Frey
#  Wyman-Manderly<->Robb-Stark
#  Wyman-Manderly<->Rodrik-Cassel
#  Wyman-Manderly<->Roose-Bolton
#  Wyman-Manderly<->Stannis-Baratheon
#  Wyman-Manderly<->Sybell-Spicer
#  Wyman-Manderly<->Theomore
#  Wyman-Manderly<->Theon-Greyjoy
#  Wynton-Stout<->Aemon-Targaryen-(Maester-Aemon)
#  Xaro-Xhoan-Daxos<->Barristan-Selmy
#  Xaro-Xhoan-Daxos<->Daenerys-Targaryen
#  Xaro-Xhoan-Daxos<->Pyat-Pree
#  Xhondo<->Quhuru-Mo
#  Xhondo<->Samwell-Tarly
#  Yandry<->Aegon-Targaryen-(son-of-Rhaegar)
#  Yandry<->Haldon
#  Yandry<->Jon-Connington
#  Yandry<->Lemore
#  Yandry<->Rolly-Duckfield
#  Yandry<->Tyrion-Lannister
#  Yandry<->Ysilla
#  Yellow-Dick<->Ramsay-Snow
#  Yellow-Dick<->Sour-Alyn
#  Yellow-Dick<->Theon-Greyjoy
#  Yezzan-zo-Qaggaz<->Nurse
#  Yezzan-zo-Qaggaz<->Penny
#  Yezzan-zo-Qaggaz<->Scar
#  Yezzan-zo-Qaggaz<->Sweets
#  Yezzan-zo-Qaggaz<->Tyrion-Lannister
#  Ygritte<->Bael-the-Bard
#  Ygritte<->Big-Boil
#  Ygritte<->Jarl
#  Ygritte<->Jon-Snow
#  Ygritte<->Mance-Rayder
#  Ygritte<->Melisandre
#  Ygritte<->Orell
#  Ygritte<->Qhorin-Halfhand
#  Ygritte<->Rattleshirt
#  Ygritte<->Ryk
#  Ygritte<->Stonesnake
#  Ygritte<->Styr
#  Ygritte<->Tormund
#  Yohn-Royce<->Anya-Waynwood
#  Yohn-Royce<->Harrold-Hardyng
#  Yohn-Royce<->Horton-Redfort
#  Yohn-Royce<->Nestor-Royce
#  Yohn-Royce<->Petyr-Baelish
#  Yohn-Royce<->Robert-Arryn
#  Yohn-Royce<->Sansa-Stark
#  Yohn-Royce<->Symond-Templeton
#  Yoren<->Amory-Lorch
#  Yoren<->Arya-Stark
#  Yoren<->Benjen-Stark
#  Yoren<->Biter
#  Yoren<->Bran-Stark
#  Yoren<->Gendry
#  Yoren<->Hot-Pie
#  Yoren<->Jaqen-Hghar
#  Yoren<->Jeor-Mormont
#  Yoren<->Joffrey-Baratheon
#  Yoren<->Jon-Snow
#  Yoren<->Koss
#  Yoren<->Lommy-Greenhands
#  Yoren<->Robb-Stark
#  Yoren<->Rorge
#  Yoren<->Syrio-Forel
#  Yoren<->Tyrion-Lannister
#  Yoren<->Woth
#  Yorko-Terys<->Arya-Stark
#  Ysilla<->Aegon-Targaryen-(son-of-Rhaegar)
#  Ysilla<->Haldon
#  Ysilla<->Lemore
#  Ysilla<->Rolly-Duckfield
#  Ysilla<->Tyrion-Lannister
#  Ysilla<->Yandry
#  Yurkhaz-zo-Yunzak<->Daenerys-Targaryen
#  Zei<->Jon-Snow
#  Zollo<->Jaime-Lannister
#  Zollo<->Rorge
#  Zollo<->Shagwell
#  Zollo<->Vargo-Hoat

# %%
print(g.getVertex('Addam-Marbrand').getConnections())
# Out:
# dict_keys([<__main__.Vertex object at 0x7fb4629ce350>, <__main__.Vertex object at 0x7fb46f1af510>, <__main__.Vertex object at 0x7fb4629c3410>, <__main__.Vertex object at 0x7fb46231b610>, <__main__.Vertex object at 0x7fb46231b650>, <__main__.Vertex object at 0x7fb46231ba90>, <__main__.Vertex object at 0x7fb462322190>, <__main__.Vertex object at 0x7fb462322bd0>, <__main__.Vertex object at 0x7fb4622b0250>, <__main__.Vertex object at 0x7fb4622c6910>, <__main__.Vertex object at 0x7fb4622c69d0>, <__main__.Vertex object at 0x7fb4622c6d10>])

# %% [markdown]
# Traverse the Nodes with Depth First Search

# %%
def traverseAll(g):
    
    visited = []
    connected = 0
    for v in g:
        if v not in visited:
            visited_v = dfs(v)
            visited += visited_v
            connected += 1
            print('\n\nNode {} has {} connected components'.format(v.getId(), len(visited_v)))
            print("\n\n")
    
    print("Total number of connected components is {}".format(connected))

# %%
def dfs(s):
    stack = [s]
    visited = []
    while stack:
        v = stack.pop()
        if v not in visited:
            visited.append(v)
            print (v.getId(), end = ", ") 
            for w in v.getConnections():
                if w not in visited:
                    stack.append(w)
                
    #print(len(visited))
    return visited

# %%
traverseAll(g)
# Out:
# Addam-Marbrand, Varys, Tywin-Lannister, Wylis-Manderly, Jaime-Lannister, Zollo, Vargo-Hoat, Rorge, Yoren, Woth, Lommy-Greenhands, Weasel, Weese, Polliver, Tickler, Sandor-Clegane, Tyrion-Lannister, Ysilla, Yandry, Rolly-Duckfield, Lemore, Jon-Connington, Robert-Baratheon, Willam-Dustin, Eddard-Stark, Wyman-Manderly, Theon-Greyjoy, Yellow-Dick, Sour-Alyn, Skinner, Ramsay-Snow, Walder-Frey-(son-of-Merrett), Wex-Pyke, Lorren, Urzen, Sybelle-Glover, Asha-Greyjoy, Victarion-Greyjoy, Wulfe, Talbert-Serry, Rodrik-Sparr, Moqorro, Daenerys-Targaryen, Yurkhaz-zo-Yunzak, Xaro-Xhoan-Daxos, Pyat-Pree, Barristan-Selmy, Widower, Steelskin, Khrazz, Spotted-Cat, Hizdahr-zo-Loraq, Skahaz-mo-Kandaq, Reznak-mo-Reznak, Galazza-Galare, Grazhar, Qezza, Miklaz, Draqaz, Mezzara, Missandei, Quentyn-Martell, Trystane-Martell, Myrcella-Baratheon, Tommen-Baratheon, Taena-of-Myr, Osney-Kettleblack, Stannis-Baratheon, William-Foxglove, Val, Tormund, Ygritte, Styr, Rattleshirt, Weeper, Othell-Yarwyck, Pypar, Todder, Jon-Snow, Zei, Wun-Weg-Wun-Dar-Wun, Selyse-Florent, Shireen-Baratheon, Pylos, Edric-Storm, Davos-Seaworth, Sybell-Spicer, Robb-Stark, Willem-Lannister, Tion-Frey, Martyn-Lannister, Kevan-Lannister, Sansa-Stark, Yohn-Royce, Symond-Templeton, Petyr-Baelish, Tomard, Jory-Cassel, Wyl-(guard), Heward, Vayon-Poole, Cersei-Lannister, Willas-Tyrell, Margaery-Tyrell, Tallad, Lambert-Turnberry, Jalabhar-Xho, Gyles-Rosby, Tanda-Stokeworth, Shae, Tysha, Symon-Silver-Tongue, Lollys-Stokeworth, Bronn, Willis-Wode, Rodrik-Cassel, Roose-Bolton, Walton, Qyburn, Robert-Strong, Randyll-Tarly, Samwell-Tarly, Xhondo, Quhuru-Mo, Theobald, Small-Paul, Lark, Softfoot, Jeor-Mormont, Thoren-Smallwood, Qhorin-Halfhand, Stonesnake, Ebben, Dalbridge, Ragwyle, Mance-Rayder, Varamyr, Thistle, Harma, Jarl, Grigg, Errok, Haggon, Bump, Squirrel, Rowan, Jeyne-Poole, Mordane, Joffrey-Baratheon, Renly-Baratheon, Steffon-Baratheon, Pycelle, Walder-Frey, Stevron-Frey, Ryman-Frey, Walder-Rivers, Lothar-Frey, Roslin-Frey, Edmure-Tully, Tytos-Blackwood, Jonos-Bracken, Jason-Mallister, Catelyn-Stark, Wendel-Manderly, Shadd, Robin-Flint, Jon-Umber-(Greatjon), Rickard-Karstark, Maege-Mormont, Dacey-Mormont, Luwin, Rickon-Stark, Osha, Mikken, Chayle, Bran-Stark, Walder-Frey-(son-of-Jammos), Stiv, Stafford-Lannister, Rickard-Stark, Brandon-Stark, Lyanna-Stark, Rhaegar-Targaryen, Viserys-Targaryen, Rhaella-Targaryen, Oberyn-Martell, Tyene-Sand, Sylva-Santagar, Garin-(orphan), Nymeria-Sand, Obara-Sand, Doran-Martell, Gregor-Clegane, Rafford, Meryn-Trant, Syrio-Forel, Arya-Stark, Yorko-Terys, Waif, Kindly-Man, Umma, Tom-of-Sevenstreams, Tansy, Lysa-Arryn, Vardis-Egen, Eon-Hunter, Colemon, Robert-Arryn, Terrance-Lynderly, Gyles-Grafton, Gerold-Grafton, Nestor-Royce, Brynden-Tully, Lyle-Crakehall, Ilyn-Payne, Loras-Tyrell, Osmund-Kettleblack, Osfryd-Kettleblack, Moon-Boy, Lancel-Lannister, Jacelyn-Bywater, Janos-Slynt, Hobb, Owen, Spare-Boot, Satin, Mully, Hareth-(Moles-Town), Rory, Leathers, Toregg, Kegs, Grenn, Halder, Rast, Alliser-Thorne, Bowen-Marsh, Wick-Whittlestick, Eddison-Tollett, Watt, Gilly, Melisandre, Sigorn, Alys-Karstark, Salladhor-Saan, Khorane-Sathmantes, Axell-Florent, Porridge, Lamprey, Alester-Florent, Cortnay-Penrose, Bryce-Caron, Guyard-Morrigen, Eldon-Estermont, Steffon-Varner, Joramun, Guncer-Sunglass, Godry-Farring, Justin-Massey, Richard-Horpe, Alysane-Mormont, Clayton-Suggs, Devan-Seaworth, Dalla, Cressen, Patchface, Meera-Reed, Leaf, Jojen-Reed, Hodor, Nan, Harren-Hoare, Aegon-I-Targaryen, Visenya-Targaryen, Rhaenys-Targaryen, Torrhen-Stark, Coldhands, Craster, Dywen, Bedwyck, Bannen, Dirk, Clubfoot-Karl, Byam-Flint, Alebelly, Hayhead, Brynden-Rivers, Kojja-Mo, Dareon, Lanna-(Happy-Port), Aemon-Targaryen-(Maester-Aemon), Wynton-Stout, Maekar-I-Targaryen, Donal-Noye, Mag-Mar-Tun-Doh-Weg, Denys-Mallister, Cotter-Pyke, Daeron-II-Targaryen, Clydas, Cellador, Chett, Alleras, Roone, Mollander, Pate-(novice), Walgrave, Gormon-Tyrell, Rosey, Quill, Leo-Tyrell, Armen, Marwyn, A ...
#
# Node Addam-Marbrand has 796 connected components
#
#
#
# Total number of connected components is 1

# %% [markdown]
# Breadth First Search to Find the Distance Between Characters

# %%
def bfs(g,s,t):
    visited = {}
    d = {}
    for v in g:
        visited[v] = False
        d[v] = float('inf')
     
    d[s] = 0
    queue = [s]
    visited[s] = True
    
    while queue:
        v = queue.pop(0)
        
        for w in v.getConnections():
            if visited[w] == False:
                visited[w] = True
                queue.append(w)
                d[w] = d[v] + 1
    print("The distance from {} to {} is {}".format(s.getId(),t.getId(), d[t]))

# %%
s = g.getVertex('Addam-Marbrand')
t = g.getVertex('Emmond')
bfs(g,s,t)
# Out:
# The distance from Addam-Marbrand to Emmond is 4

# %%
s = g.getVertex('Shitmouth')
t = g.getVertex('Trystane-Martell')
bfs(g,s,t)
# Out:
# The distance from Shitmouth to Trystane-Martell is 4
